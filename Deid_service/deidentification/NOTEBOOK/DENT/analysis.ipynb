# %%
from sqlalchemy import create_engine, text
import pandas as pd

engine = create_engine('mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/emd_serono')

# %%
df = pd.read_sql('select * from telenc limit 10', engine.connect())
columns = df.columns
len(columns)
# Out:
# 19

# %%
columns
# Out:
# Index(['TicketID', 'encounterId', 'uid', 'Caller', 'message', 'actiontaken',
#        'priority', 'assignedTo', 'assignedToId', 'pmcid', 'virtualflag',
#        'WebStatus', 'TimeTaken', 'telencLock', 'teldeleteflag', 'telencType',
#        'inpatientflag', 'refReqId', 'source'],
#       dtype='object')

# %%
['ID', 'name', 'deleteFlag', 'LabId', 'labaddress', 'labaddress2',
       'labcity', 'labstate', 'labzip', 'labphone', 'labfax', 'labemail',
       'interfaceConfigured', 'ResultLabId', 'sendoutboundresult', 'labCode',
       'labcompanyType', 'inHouseLab', 'superhubInterfaceID',
       'RepoBuildStatus', 'defaultTransmitMode', 'cirrusPractId',
       'faxDialingCountryId'],
