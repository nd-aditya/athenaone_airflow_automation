# %%
import os
import django
import sys
# Set up Django environment
sys.path.append('/Users/rohit.chouhan/NEDI/CODE/Dump/Project/DeIdentification/deIdentification')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()


from nd_api.models import DbDetailsModel, TableDetailsModel
from worker.models import Task, Chain
from django.contrib.auth.models import User
from nd_api.models.roles.rolemodel import RoleModel, get_default_permissions
from nd_scripts.create_account import create_account

def clean_db():
    RoleModel.objects.all().delete()
    User.objects.all().delete()
    DbDetailsModel.objects.all().delete()
    Chain.objects.all().delete()

# %%
table_config = {'batch_size': 1,
 'ignore_config': {'operator': 'and', 'ignore_rows': []},
 'columns_details': [{'is_phi': True,
   'mask_value': None,
   'column_name': 'uid',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': 'PATIENT_ID',
   'column_name_for_phi_table': None},
  {'is_phi': True,
   'mask_value': '<<PATIENT_NAME>>',
   'column_name': 'patient_name',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': 'MASK',
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'uname',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'upwd',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'first_name',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'last_name',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'city',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'state',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'address',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': True,
   'mask_value': None,
   'column_name': 'zipcode',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': 'ZIP_CODE',
   'column_name_for_phi_table': None},
  {'is_phi': True,
   'mask_value': None,
   'column_name': 'dob',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': 'PATIENT_DOB',
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'email',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'ssn',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'phone',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'sex',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': True,
   'mask_value': None,
   'column_name': 'register_date',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': 'DATE_OFFSET',
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'notes',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None},
  {'is_phi': False,
   'mask_value': None,
   'column_name': 'UserType',
   'ignore_column': {},
   'add_to_phi_table': False,
   'de_identification_rule': None,
   'column_name_for_phi_table': None}],
 'reference_enc_id_column': None,
 'reference_patient_id_column': 'uid'}


table_name = "users"

# %%
from qc_package.scanner import DbScanner

# %%
src_connstr = "mysql+pymysql://root:123456789@localhost:3306/nddenttest"
dest_connstr = "mysql+pymysql://root:123456789@localhost:3306/full_automation"
qc_config = {
    "PATIENT_ID": {},
    "ENCOUNTER_ID": {}
}
db_scanner = DbScanner(src_connstr, dest_connstr, qc_config)

# %%
db_scanner.scan_table(table_name, table_config)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 db_scanner.scan_table(table_name, table_config)
#
# File ~/NEDI/CODE/Dump/Project/DeIdentification/deIdentification/qc_package/scanner.py:38, in DbScanner.scan_table(self, table_name, table_config)
#      36 columns_qc_result = {}
#      37 for col_name, detector in detectors:
# ---> 38     result = detector.is_deidentified(before_rows=sample_data, after_rows=sample_data, ignore_condition=table_config["ignore_rows"])
#      39     columns_qc_result[col_name] = result
#      40 output_result = OutputSchemaForTable(sample_size=sample_size, table_name=table_name, ColumnsQCResult=columns_qc_result)
#
# KeyError: 'ignore_rows'
