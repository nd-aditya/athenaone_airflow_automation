# %%
import requests
#import pandas as pd

url = "http://localhost:8000/upload_config_from_csv/49/"

input_csv = "/Users/ndaineurocenterpa/Desktop/Soorykant/Data Dump/inc_config.csv"

files = {"file": ("all_tables.csv", open(input_csv, "rb"), "text/csv")}

response = requests.post(url, files=files)

print(response.status_code, response.json()) 
# 200
# Out:
# 200 {'success': True, 'message': 'Configuration uploaded successfully.'}
