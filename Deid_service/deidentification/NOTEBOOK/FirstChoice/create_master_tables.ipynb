# %%
import os
import django
import sys
# Set up Django environment
sys.path.append('F:\Soorykant\deidentification\deIdentification')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from core.dbPkg.phi_table.create_table import PIITable

# %%
src_db_url = 'mssql+pymssql://ndadmin:ndADMIN%402025@localhost:57546/db_flneco'
dest_db_url = 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/master'

# %%
insurance_table_config = {
    "insurance_details": {
        "primary_column_name": None,
        "upsert_instead_of_append": True,
        "tables": {
            "hcfa": {
                "primary_col": None,
                "other_required_columns": [
                    "PName",
                    "InsuredName",
                    "InsuredId",
                    "PAddressStreet",
                    "PAddressCity",
                    "InsuredAddStreet",
                    "InsuredAddCity",
                    "NameRef",
                    "SSN",
                    "EmpOrSchoolName",
                    "InsurancePlan",
                    "OtherInsuredName",
                    "OtherEmpName",
                    "OtherInsuranceName",
                    "PayorName1",
                    "PayorName2",
                    "PayorName3",
                    "PayorAddress11",
                    "PayorAddress12",
                    "PayorAddress13",
                    "PayorAddress21",
                    "PayorAddress22",
                    "PayorAddress23",
                    "PayorCity1",
                    "PayorZip1",
                    "PayorCity2",
                    "PayorZip2",
                    "PayorCity3",
                    "PayorZip3"
                ],
            }
        },
    }
}

pii = PIITable(src_db_url, dest_db_url, insurance_table_config)
pii.generate_pii_tables()
# Out:
# 2025-05-23 12:52:35,102 - deIdentification.nd_logger - INFO - Existing tables in source DB: 7407
# 2025-05-23 12:53:34,303 - deIdentification.nd_logger - INFO - Inserted batch 1 of 31 for insurance_details.
# 2025-05-23 12:53:49,153 - deIdentification.nd_logger - INFO - Inserted batch 2 of 31 for insurance_details.
# 2025-05-23 12:54:03,992 - deIdentification.nd_logger - INFO - Inserted batch 3 of 31 for insurance_details.
# 2025-05-23 12:54:19,038 - deIdentification.nd_logger - INFO - Inserted batch 4 of 31 for insurance_details.
# 2025-05-23 12:54:33,739 - deIdentification.nd_logger - INFO - Inserted batch 5 of 31 for insurance_details.
# 2025-05-23 12:54:47,753 - deIdentification.nd_logger - INFO - Inserted batch 6 of 31 for insurance_details.
# 2025-05-23 12:55:03,006 - deIdentification.nd_logger - INFO - Inserted batch 7 of 31 for insurance_details.
# 2025-05-23 12:55:17,413 - deIdentification.nd_logger - INFO - Inserted batch 8 of 31 for insurance_details.
# 2025-05-23 12:55:31,524 - deIdentification.nd_logger - INFO - Inserted batch 9 of 31 for insurance_details.
# 2025-05-23 12:55:46,275 - deIdentification.nd_logger - INFO - Inserted batch 10 of 31 for insurance_details.
# 2025-05-23 12:56:00,573 - deIdentification.nd_logger - INFO - Inserted batch 11 of 31 for insurance_details.
# 2025-05-23 12:56:14,621 - deIdentification.nd_logger - INFO - Inserted batch 12 of 31 for insurance_details.
# 2025-05-23 12:56:28,700 - deIdentification.nd_logger - INFO - Inserted batch 13 of 31 for insurance_details.
# 2025-05-23 12:56:42,311 - deIdentification.nd_logger - INFO - Inserted batch 14 of 31 for insurance_details.
# 2025-05-23 12:56:57,046 - deIdentification.nd_logger - INFO - Inserted batch 15 of 31 for insurance_details.
# 2025-05-23 12:57:10,688 - deIdentification.nd_logger - INFO - Inserted batch 16 of 31 for insurance_details.
# 2025-05-23 12:57:25,314 - deIdentification.nd_logger - INFO - Inserted batch 17 of 31 for insurance_details.
# 2025-05-23 12:57:39,049 - deIdentification.nd_logger - INFO - Inserted batch 18 of 31 for insurance_details.
# 2025-05-23 12:57:53,832 - deIdentification.nd_logger - INFO - Inserted batch 19 of 31 for insurance_details.
# 2025-05-23 12:58:07,661 - deIdentification.nd_logger - INFO - Inserted batch 20 of 31 for insurance_details.
# 2025-05-23 12:58:20,865 - deIdentification.nd_logger - INFO - Inserted batch 21 of 31 for insurance_details.
# 2025-05-23 12:58:34,460 - deIdentification.nd_logger - INFO - Inserted batch 22 of 31 for insurance_details.
# 2025-05-23 12:58:49,743 - deIdentification.nd_logger - INFO - Inserted batch 23 of 31 for insurance_details.
# 2025-05-23 12:59:04,603 - deIdentification.nd_logger - INFO - Inserted batch 24 of 31 for insurance_details.
# 2025-05-23 12:59:18,573 - deIdentification.nd_logger - INFO - Inserted batch 25 of 31 for insurance_details.
# 2025-05-23 12:59:32,512 - deIdentification.nd_logger - INFO - Inserted batch 26 of 31 for insurance_details.
# 2025-05-23 12:59:46,263 - deIdentification.nd_logger - INFO - Inserted batch 27 of 31 for insurance_details.
# 2025-05-23 13:00:00,108 - deIdentification.nd_logger - INFO - Inserted batch 28 of 31 for insurance_details.
# 2025-05-23 13:00:15,140 - deIdentification.nd_logger - INFO - Inserted batch 29 of 31 for insurance_details.
# 2025-05-23 13:00:29,141 - deIdentification.nd_logger - INFO - Inserted batch 30 of 31 for insurance_details.
# 2025-05-23 13:00:37,767 - deIdentification.nd_logger - INFO - Inserted batch 31 of 31 for insurance_details.
# 2025-05-23 13:00:37,783 - deIdentification.nd_logger - INFO - Data from table insurance_details successfully inserted/updated.

# %%
pii_table_config = {
    "pii_data_table": {
        "primary_column_name": "patient_id",
        "upsert_instead_of_append": True,
        "tables": {
            "users": {
                "primary_col": "uid",
                "other_required_columns": [
                    "uname",
                    "UserType",
                    "upwd",
                    "umobileno",
                    "upagerno",
                    "ufname",
                    "uminitial",
                    "ulname",
                    "uemail",
                    "upaddress",
                    "upcity",
                    "upPhone",
                    "dob",
                    "ssn",
                    "upaddress2",
                    "initials",
                    "ptDob",
                    "upreviousname",
                ],
            },
            "patients": {
                "primary_col": "pid",
                "other_required_columns": [
                    "employername",
                    "employeraddress",
                    "employeraddress2",
                    "employercity",
                    "employerPhone",
                    "insname",
                    "insgroupno",
                    "inssubscriberno",
                    "inscopay",
                    "insname2",
                    "insgroupno2",
                    "inssubscriberno2",
                    "inscopay2",
                    "straddress",
                    "city",
                    "insId",
                    "insId2",
                    "strAddress2",
                    "GrId",
                    "preferred_name",
                ],
            },
        },
    }
}

pii = PIITable(src_db_url, dest_db_url, pii_table_config)
pii.generate_pii_tables()
# Out:
# 2025-05-23 13:00:39,253 - deIdentification.nd_logger - INFO - Existing tables in source DB: 7407
# 2025-05-23 13:01:51,506 - deIdentification.nd_logger - INFO - Inserted batch 1 of 94 for pii_data_table.
# 2025-05-23 13:02:00,788 - deIdentification.nd_logger - INFO - Inserted batch 2 of 94 for pii_data_table.
# 2025-05-23 13:02:09,852 - deIdentification.nd_logger - INFO - Inserted batch 3 of 94 for pii_data_table.
# 2025-05-23 13:02:18,931 - deIdentification.nd_logger - INFO - Inserted batch 4 of 94 for pii_data_table.
# 2025-05-23 13:02:26,806 - deIdentification.nd_logger - INFO - Inserted batch 5 of 94 for pii_data_table.
# 2025-05-23 13:02:35,119 - deIdentification.nd_logger - INFO - Inserted batch 6 of 94 for pii_data_table.
# 2025-05-23 13:02:43,042 - deIdentification.nd_logger - INFO - Inserted batch 7 of 94 for pii_data_table.
# 2025-05-23 13:02:50,511 - deIdentification.nd_logger - INFO - Inserted batch 8 of 94 for pii_data_table.
# 2025-05-23 13:02:58,293 - deIdentification.nd_logger - INFO - Inserted batch 9 of 94 for pii_data_table.
# 2025-05-23 13:03:06,091 - deIdentification.nd_logger - INFO - Inserted batch 10 of 94 for pii_data_table.
# 2025-05-23 13:03:13,888 - deIdentification.nd_logger - INFO - Inserted batch 11 of 94 for pii_data_table.
# 2025-05-23 13:03:22,030 - deIdentification.nd_logger - INFO - Inserted batch 12 of 94 for pii_data_table.
# 2025-05-23 13:03:30,108 - deIdentification.nd_logger - INFO - Inserted batch 13 of 94 for pii_data_table.
# 2025-05-23 13:03:38,562 - deIdentification.nd_logger - INFO - Inserted batch 14 of 94 for pii_data_table.
# 2025-05-23 13:03:46,141 - deIdentification.nd_logger - INFO - Inserted batch 15 of 94 for pii_data_table.
# 2025-05-23 13:03:54,095 - deIdentification.nd_logger - INFO - Inserted batch 16 of 94 for pii_data_table.
# 2025-05-23 13:04:01,564 - deIdentification.nd_logger - INFO - Inserted batch 17 of 94 for pii_data_table.
# 2025-05-23 13:04:09,799 - deIdentification.nd_logger - INFO - Inserted batch 18 of 94 for pii_data_table.
# 2025-05-23 13:04:17,753 - deIdentification.nd_logger - INFO - Inserted batch 19 of 94 for pii_data_table.
# 2025-05-23 13:04:25,722 - deIdentification.nd_logger - INFO - Inserted batch 20 of 94 for pii_data_table.
# 2025-05-23 13:04:33,708 - deIdentification.nd_logger - INFO - Inserted batch 21 of 94 for pii_data_table.
# 2025-05-23 13:04:41,708 - deIdentification.nd_logger - INFO - Inserted batch 22 of 94 for pii_data_table.
# 2025-05-23 13:04:49,178 - deIdentification.nd_logger - INFO - Inserted batch 23 of 94 for pii_data_table.
# 2025-05-23 13:04:57,163 - deIdentification.nd_logger - INFO - Inserted batch 24 of 94 for pii_data_table.
# 2025-05-23 13:05:05,679 - deIdentification.nd_logger - INFO - Inserted batch 25 of 94 for pii_data_table.
# 2025-05-23 13:05:13,711 - deIdentification.nd_logger - INFO - Inserted batch 26 of 94 for pii_data_table.
# 2025-05-23 13:05:21,477 - deIdentification.nd_logger - INFO - Inserted batch 27 of 94 for pii_data_table.
# 2025-05-23 13:05:29,556 - deIdentification.nd_logger - INFO - Inserted batch 28 of 94 for pii_data_table.
# 2025-05-23 13:05:37,557 - deIdentification.nd_logger - INFO - Inserted batch 29 of 94 for pii_data_table.
# 2025-05-23 13:05:45,026 - deIdentification.nd_logger - INFO - Inserted batch 30 of 94 for pii_data_table.
# 2025-05-23 13:05:53,058 - deIdentification.nd_logger - INFO - Inserted batch 31 of 94 for pii_data_table.
# 2025-05-23 13:06:00,637 - deIdentification.nd_logger - INFO - Inserted batch 32 of 94 for pii_data_table.
# 2025-05-23 13:06:08,965 - deIdentification.nd_logger - INFO - Inserted batch 33 of 94 for pii_data_table.
# 2025-05-23 13:06:16,372 - deIdentification.nd_logger - INFO - Inserted batch 34 of 94 for pii_data_table.
# 2025-05-23 13:06:24,107 - deIdentification.nd_logger - INFO - Inserted batch 35 of 94 for pii_data_table.
# 2025-05-23 13:06:32,077 - deIdentification.nd_logger - INFO - Inserted batch 36 of 94 for pii_data_table.
# 2025-05-23 13:06:39,859 - deIdentification.nd_logger - INFO - Inserted batch 37 of 94 for pii_data_table.
# 2025-05-23 13:06:47,328 - deIdentification.nd_logger - INFO - Inserted batch 38 of 94 for pii_data_table.
# 2025-05-23 13:06:55,547 - deIdentification.nd_logger - INFO - Inserted batch 39 of 94 for pii_data_table.
# 2025-05-23 13:07:03,704 - deIdentification.nd_logger - INFO - Inserted batch 40 of 94 for pii_data_table.
# 2025-05-23 13:07:12,174 - deIdentification.nd_logger - INFO - Inserted batch 41 of 94 for pii_data_table.
# 2025-05-23 13:07:19,643 - deIdentification.nd_logger - INFO - Inserted batch 42 of 94 for pii_data_table.
# 2025-05-23 13:07:27,409 - deIdentification.nd_logger - INFO - Inserted batch 43 of 94 for pii_data_table.
# 2025-05-23 13:07:35,597 - deIdentification.nd_logger - INFO - Inserted batch 44 of 94 for pii_data_table.
# 2025-05-23 13:07:43,036 - deIdentification.nd_logger - INFO - Inserted batch 45 of 94 for pii_data_table.
# 2025-05-23 13:07:51,317 - deIdentification.nd_logger - INFO - Inserted batch 46 of 94 for pii_data_table.
# 2025-05-23 13:07:59,459 - deIdentification.nd_logger - INFO - Inserted batch 47 of 94 for pii_data_table.
# 2025-05-23 13:08:06,678 - deIdentification.nd_logger - INFO - Inserted batch 48 of 94 for pii_data_table.
# 2025-05-23 13:08:14,788 - deIdentification.nd_logger - INFO - Inserted batch 49 of 94 for pii_data_table.
# 2025-05-23 13:08:22,179 - deIdentification.nd_logger - INFO - Inserted batch 50 of 94 for pii_data_table.
# 2025-05-23 13:08:30,039 - deIdentification.nd_logger - INFO - Inserted batch 51 of 94 for pii_data_table.
# 2025-05-23 13:08:37,931 - deIdentification.nd_logger - INFO - Inserted batch 52 of 94 for pii_data_table.
# 2025-05-23 13:08:45,728 - deIdentification.nd_logger - INFO - Inserted batch 53 of 94 for pii_data_table.
# 2025-05-23 13:08:53,979 - deIdentification.nd_logger - INFO - Inserted batch 54 of 94 for pii_data_table.
# 2025-05-23 13:09:01,948 - deIdentification.nd_logger - INFO - Inserted batch 55 of 94 for pii_data_table.
# 2025-05-23 13:09:09,152 - deIdentification.nd_logger - INFO - Inserted batch 56 of 94 for pii_data_table.
# 2025-05-23 13:09:17,106 - deIdentification.nd_logger - INFO - Inserted batch 57 of 94 for pii_data_table.
# 2025-05-23 13:09:25,263 - deIdentification.nd_logger - INFO - Inserted batch 58 of 94 for pii_data_table.
# 2025-05-23 13:09:33,232 - deIdentification.nd_logger - INFO - Inserted batch 59 of 94 for pii_data_table.
# 2025-05-23 13:09:41,514 - deIdentification.nd_logger - INFO - Inserted batch 60 of 94 for pii_data_table.
# 2025-05-23 13:09:48,999 - deIdentification.nd_logger - INFO - Inserted batch 61 of 94 for pii_data_table.
# 2025-05-23 13:09:57,187 - deIdentification.nd_logger - INFO - Inserted batch 62 of 94 for pii_data_table.
# 2025-05-23 13:10:05,156 - deIdentification.nd_logger - INFO - Inserted batch 63 of 94 for pii_data_table.
# 2025-05-23 13:10:12,641 - deIdentification.nd_logger - INFO - Inserted batch 64 of 94 for pii_data_table.
# 2025-05-23 13:10:21,048 - deIdentification.nd_logger - INFO - Inserted batch 65 of 94 for pii_data_table.
# 2025-05-23 13:10:28,643 - deIdentification.nd_logger - INFO - Inserted batch 66 of 94 for pii_data_table.
# 2025-05-23 13:10:36,800 - deIdentification.nd_logger - INFO - Inserted batch 67 of 94 for pii_data_table.
# 2025-05-23 13:10:44,785 - deIdentification.nd_logger - INFO - Inserted batch 68 of 94 for pii_data_table.
# 2025-05-23 13:10:52,770 - deIdentification.nd_logger - INFO - Inserted batch 69 of 94 for pii_data_table.
# 2025-05-23 13:11:00,598 - deIdentification.nd_logger - INFO - Inserted batch 70 of 94 for pii_data_table.
# 2025-05-23 13:11:08,802 - deIdentification.nd_logger - INFO - Inserted batch 71 of 94 for pii_data_table.
# 2025-05-23 13:11:16,990 - deIdentification.nd_logger - INFO - Inserted batch 72 of 94 for pii_data_table.
# 2025-05-23 13:11:24,757 - deIdentification.nd_logger - INFO - Inserted batch 73 of 94 for pii_data_table.
# 2025-05-23 13:11:32,742 - deIdentification.nd_logger - INFO - Inserted batch 74 of 94 for pii_data_table.
# 2025-05-23 13:11:40,320 - deIdentification.nd_logger - INFO - Inserted batch 75 of 94 for pii_data_table.
# 2025-05-23 13:11:48,399 - deIdentification.nd_logger - INFO - Inserted batch 76 of 94 for pii_data_table.
# 2025-05-23 13:11:56,025 - deIdentification.nd_logger - INFO - Inserted batch 77 of 94 for pii_data_table.
# 2025-05-23 13:12:04,213 - deIdentification.nd_logger - INFO - Inserted batch 78 of 94 for pii_data_table.
# 2025-05-23 13:12:12,635 - deIdentification.nd_logger - INFO - Inserted batch 79 of 94 for pii_data_table.
# 2025-05-23 13:12:20,777 - deIdentification.nd_logger - INFO - Inserted batch 80 of 94 for pii_data_table.
# 2025-05-23 13:12:28,668 - deIdentification.nd_logger - INFO - Inserted batch 81 of 94 for pii_data_table.
# 2025-05-23 13:12:36,481 - deIdentification.nd_logger - INFO - Inserted batch 82 of 94 for pii_data_table.
# 2025-05-23 13:12:44,482 - deIdentification.nd_logger - INFO - Inserted batch 83 of 94 for pii_data_table.
# 2025-05-23 13:12:52,607 - deIdentification.nd_logger - INFO - Inserted batch 84 of 94 for pii_data_table.
# 2025-05-23 13:13:00,092 - deIdentification.nd_logger - INFO - Inserted batch 85 of 94 for pii_data_table.
# 2025-05-23 13:13:08,265 - deIdentification.nd_logger - INFO - Inserted batch 86 of 94 for pii_data_table.
# 2025-05-23 13:13:16,719 - deIdentification.nd_logger - INFO - Inserted batch 87 of 94 for pii_data_table.
# 2025-05-23 13:13:24,047 - deIdentification.nd_logger - INFO - Inserted batch 88 of 94 for pii_data_table.
# 2025-05-23 13:13:32,454 - deIdentification.nd_logger - INFO - Inserted batch 89 of 94 for pii_data_table.
# 2025-05-23 13:13:40,611 - deIdentification.nd_logger - INFO - Inserted batch 90 of 94 for pii_data_table.
# 2025-05-23 13:13:47,971 - deIdentification.nd_logger - INFO - Inserted batch 91 of 94 for pii_data_table.
# 2025-05-23 13:13:56,441 - deIdentification.nd_logger - INFO - Inserted batch 92 of 94 for pii_data_table.
# 2025-05-23 13:14:04,051 - deIdentification.nd_logger - INFO - Inserted batch 93 of 94 for pii_data_table.
# 2025-05-23 13:14:06,863 - deIdentification.nd_logger - INFO - Inserted batch 94 of 94 for pii_data_table.
# 2025-05-23 13:14:06,879 - deIdentification.nd_logger - INFO - Data from table pii_data_table successfully inserted/updated.
# 2025-05-23 13:15:11,494 - deIdentification.nd_logger - INFO - Inserted batch 1 of 92 for pii_data_table.
# 2025-05-23 13:15:24,948 - deIdentification.nd_logger - INFO - Inserted batch 2 of 92 for pii_data_table.
# 2025-05-23 13:15:36,964 - deIdentification.nd_logger - INFO - Inserted batch 3 of 92 for pii_data_table.
# 2025-05-23 13:15:49,403 - deIdentification.nd_logger - INFO - Inserted batch 4 of 92 for pii_data_table.
# 2025-05-23 13:16:00,701 - deIdentification.nd_logger - INFO - Inserted batch 5 of 92 for pii_data_table.
# 2025-05-23 13:16:12,233 - deIdentification.nd_logger - INFO - Inserted batch 6 of 92 for pii_data_table.
# 2025-05-23 13:16:23,484 - deIdentification.nd_logger - INFO - Inserted batch 7 of 92 for pii_data_table.
# 2025-05-23 13:16:35,203 - deIdentification.nd_logger - INFO - Inserted batch 8 of 92 for pii_data_table.
# 2025-05-23 13:16:46,751 - deIdentification.nd_logger - INFO - Inserted batch 9 of 92 for pii_data_table.
# 2025-05-23 13:16:57,579 - deIdentification.nd_logger - INFO - Inserted batch 10 of 92 for pii_data_table.
# 2025-05-23 13:17:09,127 - deIdentification.nd_logger - INFO - Inserted batch 11 of 92 for pii_data_table.
# 2025-05-23 13:17:20,488 - deIdentification.nd_logger - INFO - Inserted batch 12 of 92 for pii_data_table.
# 2025-05-23 13:17:31,942 - deIdentification.nd_logger - INFO - Inserted batch 13 of 92 for pii_data_table.
# 2025-05-23 13:17:43,100 - deIdentification.nd_logger - INFO - Inserted batch 14 of 92 for pii_data_table.
# 2025-05-23 13:17:54,788 - deIdentification.nd_logger - INFO - Inserted batch 15 of 92 for pii_data_table.
# 2025-05-23 13:18:06,320 - deIdentification.nd_logger - INFO - Inserted batch 16 of 92 for pii_data_table.
# 2025-05-23 13:18:17,978 - deIdentification.nd_logger - INFO - Inserted batch 17 of 92 for pii_data_table.
# 2025-05-23 13:18:28,307 - deIdentification.nd_logger - INFO - Inserted batch 18 of 92 for pii_data_table.
# 2025-05-23 13:18:39,667 - deIdentification.nd_logger - INFO - Inserted batch 19 of 92 for pii_data_table.
# 2025-05-23 13:18:50,730 - deIdentification.nd_logger - INFO - Inserted batch 20 of 92 for pii_data_table.
# 2025-05-23 13:19:01,778 - deIdentification.nd_logger - INFO - Inserted batch 21 of 92 for pii_data_table.
# 2025-05-23 13:19:12,217 - deIdentification.nd_logger - INFO - Inserted batch 22 of 92 for pii_data_table.
# 2025-05-23 13:19:23,296 - deIdentification.nd_logger - INFO - Inserted batch 23 of 92 for pii_data_table.
# 2025-05-23 13:19:34,312 - deIdentification.nd_logger - INFO - Inserted batch 24 of 92 for pii_data_table.
# 2025-05-23 13:19:45,454 - deIdentification.nd_logger - INFO - Inserted batch 25 of 92 for pii_data_table.
# 2025-05-23 13:19:56,423 - deIdentification.nd_logger - INFO - Inserted batch 26 of 92 for pii_data_table.
# 2025-05-23 13:20:07,237 - deIdentification.nd_logger - INFO - Inserted batch 27 of 92 for pii_data_table.
# 2025-05-23 13:20:18,472 - deIdentification.nd_logger - INFO - Inserted batch 28 of 92 for pii_data_table.
# 2025-05-23 13:20:29,895 - deIdentification.nd_logger - INFO - Inserted batch 29 of 92 for pii_data_table.
# 2025-05-23 13:20:40,771 - deIdentification.nd_logger - INFO - Inserted batch 30 of 92 for pii_data_table.
# 2025-05-23 13:20:52,178 - deIdentification.nd_logger - INFO - Inserted batch 31 of 92 for pii_data_table.
# 2025-05-23 13:21:02,554 - deIdentification.nd_logger - INFO - Inserted batch 32 of 92 for pii_data_table.
# 2025-05-23 13:21:13,508 - deIdentification.nd_logger - INFO - Inserted batch 33 of 92 for pii_data_table.
# 2025-05-23 13:21:24,415 - deIdentification.nd_logger - INFO - Inserted batch 34 of 92 for pii_data_table.
# 2025-05-23 13:21:35,119 - deIdentification.nd_logger - INFO - Inserted batch 35 of 92 for pii_data_table.
# 2025-05-23 13:21:46,151 - deIdentification.nd_logger - INFO - Inserted batch 36 of 92 for pii_data_table.
# 2025-05-23 13:21:57,105 - deIdentification.nd_logger - INFO - Inserted batch 37 of 92 for pii_data_table.
# 2025-05-23 13:22:09,059 - deIdentification.nd_logger - INFO - Inserted batch 38 of 92 for pii_data_table.
# 2025-05-23 13:22:19,123 - deIdentification.nd_logger - INFO - Inserted batch 39 of 92 for pii_data_table.
# 2025-05-23 13:22:30,717 - deIdentification.nd_logger - INFO - Inserted batch 40 of 92 for pii_data_table.
# 2025-05-23 13:22:41,828 - deIdentification.nd_logger - INFO - Inserted batch 41 of 92 for pii_data_table.
# 2025-05-23 13:22:52,688 - deIdentification.nd_logger - INFO - Inserted batch 42 of 92 for pii_data_table.
# 2025-05-23 13:23:03,829 - deIdentification.nd_logger - INFO - Inserted batch 43 of 92 for pii_data_table.
# 2025-05-23 13:23:14,190 - deIdentification.nd_logger - INFO - Inserted batch 44 of 92 for pii_data_table.
# 2025-05-23 13:23:25,550 - deIdentification.nd_logger - INFO - Inserted batch 45 of 92 for pii_data_table.
# 2025-05-23 13:23:36,363 - deIdentification.nd_logger - INFO - Inserted batch 46 of 92 for pii_data_table.
# 2025-05-23 13:23:46,744 - deIdentification.nd_logger - INFO - Inserted batch 47 of 92 for pii_data_table.
# 2025-05-23 13:23:57,604 - deIdentification.nd_logger - INFO - Inserted batch 48 of 92 for pii_data_table.
# 2025-05-23 13:24:08,683 - deIdentification.nd_logger - INFO - Inserted batch 49 of 92 for pii_data_table.
# 2025-05-23 13:24:19,856 - deIdentification.nd_logger - INFO - Inserted batch 50 of 92 for pii_data_table.
# 2025-05-23 13:24:30,263 - deIdentification.nd_logger - INFO - Inserted batch 51 of 92 for pii_data_table.
# 2025-05-23 13:24:41,233 - deIdentification.nd_logger - INFO - Inserted batch 52 of 92 for pii_data_table.
# 2025-05-23 13:24:52,187 - deIdentification.nd_logger - INFO - Inserted batch 53 of 92 for pii_data_table.
# 2025-05-23 13:25:03,203 - deIdentification.nd_logger - INFO - Inserted batch 54 of 92 for pii_data_table.
# 2025-05-23 13:25:13,329 - deIdentification.nd_logger - INFO - Inserted batch 55 of 92 for pii_data_table.
# 2025-05-23 13:25:25,330 - deIdentification.nd_logger - INFO - Inserted batch 56 of 92 for pii_data_table.
# 2025-05-23 13:25:36,409 - deIdentification.nd_logger - INFO - Inserted batch 57 of 92 for pii_data_table.
# 2025-05-23 13:25:47,347 - deIdentification.nd_logger - INFO - Inserted batch 58 of 92 for pii_data_table.
# 2025-05-23 13:25:58,270 - deIdentification.nd_logger - INFO - Inserted batch 59 of 92 for pii_data_table.
# 2025-05-23 13:26:09,537 - deIdentification.nd_logger - INFO - Inserted batch 60 of 92 for pii_data_table.
# 2025-05-23 13:26:19,662 - deIdentification.nd_logger - INFO - Inserted batch 61 of 92 for pii_data_table.
# 2025-05-23 13:26:30,663 - deIdentification.nd_logger - INFO - Inserted batch 62 of 92 for pii_data_table.
# 2025-05-23 13:26:41,242 - deIdentification.nd_logger - INFO - Inserted batch 63 of 92 for pii_data_table.
# 2025-05-23 13:26:52,337 - deIdentification.nd_logger - INFO - Inserted batch 64 of 92 for pii_data_table.
# 2025-05-23 13:27:03,510 - deIdentification.nd_logger - INFO - Inserted batch 65 of 92 for pii_data_table.
# 2025-05-23 13:27:14,198 - deIdentification.nd_logger - INFO - Inserted batch 66 of 92 for pii_data_table.
# 2025-05-23 13:27:25,637 - deIdentification.nd_logger - INFO - Inserted batch 67 of 92 for pii_data_table.
# 2025-05-23 13:27:35,778 - deIdentification.nd_logger - INFO - Inserted batch 68 of 92 for pii_data_table.
# 2025-05-23 13:27:46,763 - deIdentification.nd_logger - INFO - Inserted batch 69 of 92 for pii_data_table.
# 2025-05-23 13:27:57,655 - deIdentification.nd_logger - INFO - Inserted batch 70 of 92 for pii_data_table.
# 2025-05-23 13:28:08,749 - deIdentification.nd_logger - INFO - Inserted batch 71 of 92 for pii_data_table.
# 2025-05-23 13:28:19,500 - deIdentification.nd_logger - INFO - Inserted batch 72 of 92 for pii_data_table.
# 2025-05-23 13:28:30,204 - deIdentification.nd_logger - INFO - Inserted batch 73 of 92 for pii_data_table.
# 2025-05-23 13:28:41,283 - deIdentification.nd_logger - INFO - Inserted batch 74 of 92 for pii_data_table.
# 2025-05-23 13:28:52,159 - deIdentification.nd_logger - INFO - Inserted batch 75 of 92 for pii_data_table.
# 2025-05-23 13:29:02,457 - deIdentification.nd_logger - INFO - Inserted batch 76 of 92 for pii_data_table.
# 2025-05-23 13:29:13,301 - deIdentification.nd_logger - INFO - Inserted batch 77 of 92 for pii_data_table.
# 2025-05-23 13:29:23,927 - deIdentification.nd_logger - INFO - Inserted batch 78 of 92 for pii_data_table.
# 2025-05-23 13:29:34,913 - deIdentification.nd_logger - INFO - Inserted batch 79 of 92 for pii_data_table.
# 2025-05-23 13:29:45,007 - deIdentification.nd_logger - INFO - Inserted batch 80 of 92 for pii_data_table.
# 2025-05-23 13:29:56,024 - deIdentification.nd_logger - INFO - Inserted batch 81 of 92 for pii_data_table.
# 2025-05-23 13:30:07,134 - deIdentification.nd_logger - INFO - Inserted batch 82 of 92 for pii_data_table.
# 2025-05-23 13:30:17,979 - deIdentification.nd_logger - INFO - Inserted batch 83 of 92 for pii_data_table.
# 2025-05-23 13:30:28,417 - deIdentification.nd_logger - INFO - Inserted batch 84 of 92 for pii_data_table.
# 2025-05-23 13:30:38,605 - deIdentification.nd_logger - INFO - Inserted batch 85 of 92 for pii_data_table.
# 2025-05-23 13:30:49,512 - deIdentification.nd_logger - INFO - Inserted batch 86 of 92 for pii_data_table.
# 2025-05-23 13:31:00,123 - deIdentification.nd_logger - INFO - Inserted batch 87 of 92 for pii_data_table.
# 2025-05-23 13:31:11,373 - deIdentification.nd_logger - INFO - Inserted batch 88 of 92 for pii_data_table.
# 2025-05-23 13:31:22,562 - deIdentification.nd_logger - INFO - Inserted batch 89 of 92 for pii_data_table.
# 2025-05-23 13:31:32,750 - deIdentification.nd_logger - INFO - Inserted batch 90 of 92 for pii_data_table.
# 2025-05-23 13:31:43,720 - deIdentification.nd_logger - INFO - Inserted batch 91 of 92 for pii_data_table.
# 2025-05-23 13:31:45,470 - deIdentification.nd_logger - INFO - Inserted batch 92 of 92 for pii_data_table.
# 2025-05-23 13:31:45,486 - deIdentification.nd_logger - INFO - Data from table pii_data_table successfully inserted/updated.
