# %%
import os
import django
import sys
# Set up Django environment
sys.path.append('/Users/rohit.chouhan/NEDI/CODE/Dump/Project/DeIdentification/deIdentification')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()


from nd_api.models import DbDetailsModel, TableDetailsModel
from worker.models import Task, Chain
from django.contrib.auth.models import User
from keycloakauth.rolemodel import RoleModel, get_default_permissions
from nd_scripts.create_account import create_account
from nd_api.views.db_views import create_stats_generation_tasks
from core.process.main import start_de_identification_for_table
from nd_api.views.de_identification_task import create_deidentification_task
def clean_db():
    RoleModel.objects.all().delete()
    User.objects.all().delete()
    DbDetailsModel.objects.all().delete()
    Chain.objects.all().delete()

# %%
srcdb = "snowflake://rohitchouhan:Nd%4012345@ltawxcm-eg22355/AUTOMATION_TESTING/PUBLIC?warehouse=COMPUTE_WH"
destdb = "mysql+pymysql://root:123456789@localhost:3306/snow_final"

db_model = DbDetailsModel.objects.get(
    db_name="snow_test",
    # source_db_config={"connection_string": srcdb},
    # destination_db_config={"connection_string": destdb},
)

# %%
db_model.run_config = {
    "mapping_db_config": {
        "connection_string": "mysql+pymysql://root:123456789@localhost:3306/nddenttest_mapping",
        "inhouse_mapping_table": False
    }
}
db_model.save()

# %%
create_stats_generation_tasks(db_obj=db_model)
# Out:
# {'message': 'Stats Generation Task created. task id: 24'}

# %%
db_model.tables_details.
# Out:
# <QuerySet [<TableDetailsModel: patienttestdata - snow_test - 4>]>

# %%
db = DbDetailsModel.objects.all().first()
# db.run_config['pii_config'] = {
#     "connection_str": "",
#     "config": {}
# }
# db.save()
db.run_config['pii_config']
# Out:
# {'config': {},
#  'connection_str': 'mysql+pymysql://root:123456789@localhost:3306/nddenttest_mapping'}

# %%
# Out:
# <DbDetailsModel: DbDetailsModel object (1)>

# %%
table = TableDetailsModel.objects.get(table_name="users")

# %%
tasks, chain = create_deidentification_task(table)
# Out:
# 2025-01-26 15:44:02,320 - deIdentification.nd_logger - WARNING - Table users does not exist and cannot be dropped.

# %%
tasks
# Out:
# [Task(id=38, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=39, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=40, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=41, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=42, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=43, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=44, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=45, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=46, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=47, type=core.process.main.start_de_identification_for_table, arguments=({'table_id': 3, 'bat...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0),
#  Task(id=48, type=nd_api.views.de_identification_task.marked_complete_and_clean_up_tasks, arguments=({'table_id': 3, 'cha...), status=0, num_dependencies=10, num_dependencies_pending=10, failure_count=0)]

# %%
task = Task.objects.get(id=36)
task.remarks
# Out:
# {'exception': {'type': 'OperationalError',
#   'message': '(pymysql.err.OperationalError) (2003, "Can\'t connect to MySQL server on \'localhost\' ([Errno 111] Connection refused)")\n(Background on this error at: https://sqlalche.me/e/20/e3q8)',
#   'traceback': ['  File "/nd_deployment/deIdentification/worker/models/task.py", line 371, in run\n    task_output = fn(**kwargs)\n',
#    '  File "/nd_deployment/deIdentification/core/process/main.py", line 123, in start_de_identification_for_table\n    all_rows = source_db_connection.get_rows(\n',
#    '  File "/nd_deployment/deIdentification/core/dbPkg/dbhandler.py", line 161, in get_rows\n    table = Table(table_name, self.metadata, autoload_with=self.engine)\n',
#    '  File "<string>", line 2, in __new__\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/util/deprecations.py", line 281, in warned\n    return fn(*args, **kwargs)  # type: ignore[no-any-return]\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/sql/schema.py", line 427, in __new__\n    return cls._new(*args, **kw)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/sql/schema.py", line 482, in _new\n    metadata._remove_table(name, schema)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/util/langhelpers.py", line 146, in __exit__\n    raise exc_value.with_traceback(exc_tb)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/sql/schema.py", line 477, in _new\n    table.__init__(name, metadata, *args, _no_init=False, **kw)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/sql/schema.py", line 857, in __init__\n    self._autoload(\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/sql/schema.py", line 887, in _autoload\n    insp = inspection.inspect(autoload_with)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/inspection.py", line 140, in inspect\n    ret = reg(subject)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/reflection.py", line 312, in _engine_insp\n    return Inspector._construct(Inspector._init_engine, bind)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/reflection.py", line 245, in _construct\n    init(self, bind)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/reflection.py", line 256, in _init_engine\n    engine.connect().close()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py", line 3278, in connect\n    return self._connection_cls(self)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py", line 148, in __init__\n    Connection._handle_dbapi_exception_noconnection(\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py", line 2442, in _handle_dbapi_exception_noconnection\n    raise sqlalchemy_exception.with_traceback(exc_info[2]) from e\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py", line 146, in __init__\n    self._dbapi_connection = engine.raw_connection()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py", line 3302, in raw_connection\n    return self.pool.connect()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py", line 449, in connect\n    return _ConnectionFairy._checkout(self)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py", line 1263, in _checkout\n    fairy = _ConnectionRecord.checkout(pool)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py", line 712, in checkout\n    rec = pool._do_get()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/impl.py", line 180, in _do_get\n    self._dec_overflow()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/util/langhelpers.py", line 146, in __exit__\n    raise exc_value.with_traceback(exc_tb)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/impl.py", line 177, in _do_get\n    return self._create_connection()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py", line 390, in _create_connection\n    return _ConnectionRecord(self)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py", line 674, in __init__\n    self.__connect()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py", line 901, in __connect\n    pool.logger.debug("Error on connect(): %s", e)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/util/langhelpers.py", line 146, in __exit__\n    raise exc_value.with_traceback(exc_tb)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py", line 896, in __connect\n    self.dbapi_connection = connection = pool._invoke_creator(self)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/create.py", line 643, in connect\n    return dialect.connect(*cargs, **cparams)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/default.py", line 621, in connect\n    return self.loaded_dbapi.connect(*cargs, **cparams)\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/pymysql/connections.py", line 361, in __init__\n    self.connect()\n',
#    '  File "/usr/local/lib/python3.9/dist-packages/pymysql/connections.py", line 716, in connect\n    raise exc\n']}}

# %%
Chain.objects.all().delete()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/backends/base/base.py:308, in BaseDatabaseWrapper._cursor(self, name)
#     307 with self.wrap_database_errors:
# --> 308     return self._prepare_cursor(self.create_cursor(name))
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/utils/asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/backends/postgresql/base.py:330, in DatabaseWrapper.create_cursor(self, name)
#     329 else:
# --> 330     cursor = self.connection.cursor()
#     332 if is_psycopg3:
#     333     # Register the cursor timezone only if the connection disagrees, to
#     334     # avoid copying the adapter map.
#
# InterfaceError: connection already closed
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 Chain.objects.all().delete()
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/models/query.py:1147, in QuerySet.delete(self)
#    1144 del_query.query.clear_ordering(force=True)
#    1146 collector = Collector(using=del_query.db, origin=self)
# -> 1147 collector.collect(del_query)
#    1148 deleted, _rows_count = collector.delete()
#    1150 # Clear the result cache, in case this QuerySet gets reused.
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/models/deletion.py:284, in Collector.collect(self, objs, source, nullable, collect_related, source_attr, reverse_dependency, keep_parents, fail_on_restricted)
#     282     self.fast_deletes.append(objs)
#     283     return
# --> 284 new_objs = self.add(
#     285     objs, source, nullable, reverse_dependency=reverse_dependency
#     286 )
#     287 if not new_objs:
#     288     return
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/models/deletion.py:126, in Collector.add(self, objs, source, nullable, reverse_dependency)
#     118 def add(self, objs, source=None, nullable=False, reverse_dependency=False):
#     119     """
#     120     Add 'objs' to the collection of objects to be deleted.  If the call is
#     121     the result of a cascade, 'source' should be the model that caused it,
#    (...)
#     124     Return a list of all objects that were not already collected.
#     125     """
# --> 126     if not objs:
#     127         return []
#     128     new_objs = []
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/models/query.py:412, in QuerySet.__bool__(self)
#     411 def __bool__(self):
# --> 412     self._fetch_all()
#     413     return bool(self._result_cache)
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/models/query.py:1881, in QuerySet._fetch_all(self)
#    1879 def _fetch_all(self):
#    1880     if self._result_cache is None:
# -> 1881         self._result_cache = list(self._iterable_class(self))
#    1882     if self._prefetch_related_lookups and not self._prefetch_done:
#    1883         self._prefetch_related_objects()
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/models/query.py:91, in ModelIterable.__iter__(self)
#      88 compiler = queryset.query.get_compiler(using=db)
#      89 # Execute the query. This will also fill compiler.select, klass_info,
#      90 # and annotations.
# ---> 91 results = compiler.execute_sql(
#      92     chunked_fetch=self.chunked_fetch, chunk_size=self.chunk_size
#      93 )
#      94 select, klass_info, annotation_col_map = (
#      95     compiler.select,
#      96     compiler.klass_info,
#      97     compiler.annotation_col_map,
#      98 )
#      99 model_cls = klass_info["model"]
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/models/sql/compiler.py:1560, in SQLCompiler.execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1558     cursor = self.connection.chunked_cursor()
#    1559 else:
# -> 1560     cursor = self.connection.cursor()
#    1561 try:
#    1562     cursor.execute(sql, params)
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/utils/asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/backends/base/base.py:330, in BaseDatabaseWrapper.cursor(self)
#     327 @async_unsafe
#     328 def cursor(self):
#     329     """Create a cursor, opening a connection if necessary."""
# --> 330     return self._cursor()
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/backends/base/base.py:308, in BaseDatabaseWrapper._cursor(self, name)
#     306 self.ensure_connection()
#     307 with self.wrap_database_errors:
# --> 308     return self._prepare_cursor(self.create_cursor(name))
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/utils.py:91, in DatabaseErrorWrapper.__exit__(self, exc_type, exc_value, traceback)
#      89 if dj_exc_type not in (DataError, IntegrityError):
#      90     self.wrapper.errors_occurred = True
# ---> 91 raise dj_exc_value.with_traceback(traceback) from exc_value
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/backends/base/base.py:308, in BaseDatabaseWrapper._cursor(self, name)
#     306 self.ensure_connection()
#     307 with self.wrap_database_errors:
# --> 308     return self._prepare_cursor(self.create_cursor(name))
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/utils/asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/final_automation/lib/python3.9/site-packages/django/db/backends/postgresql/base.py:330, in DatabaseWrapper.create_cursor(self, name)
#     326     cursor = self.connection.cursor(
#     327         name, scrollable=False, withhold=self.connection.autocommit
#     328     )
#     329 else:
# --> 330     cursor = self.connection.cursor()
#     332 if is_psycopg3:
#     333     # Register the cursor timezone only if the connection disagrees, to
#     334     # avoid copying the adapter map.
#     335     tzloader = self.connection.adapters.get_loader(TIMESTAMPTZ_OID, Format.TEXT)
#
# InterfaceError: connection already closed

# %%
userconf = {
    "batch_size": 1000,
    "ignore_rows": {},
    "columns_details": [
        {
            "is_phi": True,
            "column_name": "patientid",
            "ignore_rows": {},
            "add_to_phi_table": False,
            "de_identification_rule": "MASK",
            "mask_value": "<<PATIENT_ID>>",
            "column_name_for_phi_table": None,
        },
        {
            "is_phi": False,
            "column_name": "patientname",
            "ignore_rows": {},
            "add_to_phi_table": False,
            "de_identification_rule": None,
            "column_name_for_phi_table": None,
        },
        {
            "is_phi": False,
            "column_name": "testname",
            "ignore_rows": {},
            "add_to_phi_table": False,
            "de_identification_rule": None,
            "column_name_for_phi_table": None,
        },
        {
            "is_phi": False,
            "column_name": "testresult",
            "ignore_rows": {},
            "add_to_phi_table": False,
            "de_identification_rule": None,
            "column_name_for_phi_table": None,
        },
        {
            "is_phi": True,
            "column_name": "testdate",
            "ignore_rows": {},
            "add_to_phi_table": False,
            "de_identification_rule": "PATIENT_DOB",
            "column_name_for_phi_table": None,
        },
        {
            "is_phi": False,
            "column_name": "doctorname",
            "ignore_rows": {},
            "add_to_phi_table": False,
            "de_identification_rule": None,
            "column_name_for_phi_table": None,
        },
    ],
    "reference_enc_id_column": None,
    "reference_patient_id_column": None,
}

# %%
table.table_details_for_ui = userconf
table.save()
