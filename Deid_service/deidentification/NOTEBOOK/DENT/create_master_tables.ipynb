# %%
import os
import django
import sys
# Set up Django environment
sys.path.append('D:\ssuman\deidentification\deIdentification')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from core.dbPkg.phi_table.create_table import PIITable

# %%
src_db_url = 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/emd_serono'
dest_db_url = 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/emd_serono_master'

# %%
insurance_table_config = {
    "insurance_details": {
        "primary_column_name": None,
        "upsert_instead_of_append": True,
        "tables": {
            "hcfa": {
                "primary_col": None,
                "other_required_columns": [
                    "PName",
                    "InsuredName",
                    "InsuredId",
                    "PAddressStreet",
                    "PAddressCity",
                    "InsuredAddStreet",
                    "InsuredAddCity",
                    "NameRef",
                    "SSN",
                    "EmpOrSchoolName",
                    "InsurancePlan",
                    "OtherInsuredName",
                    "OtherEmpName",
                    "OtherInsuranceName",
                    "PayorName1",
                    "PayorName2",
                    "PayorName3",
                    "PayorAddress11",
                    "PayorAddress12",
                    "PayorAddress13",
                    "PayorAddress21",
                    "PayorAddress22",
                    "PayorAddress23",
                    "PayorCity1",
                    "PayorZip1",
                    "PayorCity2",
                    "PayorZip2",
                    "PayorCity3",
                    "PayorZip3"
                ],
            }
        },
    }
}

pii = PIITable(src_db_url, dest_db_url, insurance_table_config)
pii.generate_pii_tables()
# Out:
# 2025-06-05 12:17:33,764 - deIdentification.nd_logger - INFO - Existing tables in source DB: 51
# 2025-06-05 12:17:53,839 - deIdentification.nd_logger - INFO - Inserted batch 1 of 48 for insurance_details.
# 2025-06-05 12:17:59,594 - deIdentification.nd_logger - INFO - Inserted batch 2 of 48 for insurance_details.
# 2025-06-05 12:18:04,967 - deIdentification.nd_logger - INFO - Inserted batch 3 of 48 for insurance_details.
# 2025-06-05 12:18:10,673 - deIdentification.nd_logger - INFO - Inserted batch 4 of 48 for insurance_details.
# 2025-06-05 12:18:16,385 - deIdentification.nd_logger - INFO - Inserted batch 5 of 48 for insurance_details.
# 2025-06-05 12:18:21,671 - deIdentification.nd_logger - INFO - Inserted batch 6 of 48 for insurance_details.
# 2025-06-05 12:18:27,545 - deIdentification.nd_logger - INFO - Inserted batch 7 of 48 for insurance_details.
# 2025-06-05 12:18:33,671 - deIdentification.nd_logger - INFO - Inserted batch 8 of 48 for insurance_details.
# 2025-06-05 12:18:39,279 - deIdentification.nd_logger - INFO - Inserted batch 9 of 48 for insurance_details.
# 2025-06-05 12:18:45,306 - deIdentification.nd_logger - INFO - Inserted batch 10 of 48 for insurance_details.
# 2025-06-05 12:18:51,368 - deIdentification.nd_logger - INFO - Inserted batch 11 of 48 for insurance_details.
# 2025-06-05 12:18:57,151 - deIdentification.nd_logger - INFO - Inserted batch 12 of 48 for insurance_details.
# 2025-06-05 12:19:02,670 - deIdentification.nd_logger - INFO - Inserted batch 13 of 48 for insurance_details.
# 2025-06-05 12:19:08,735 - deIdentification.nd_logger - INFO - Inserted batch 14 of 48 for insurance_details.
# 2025-06-05 12:19:14,616 - deIdentification.nd_logger - INFO - Inserted batch 15 of 48 for insurance_details.
# 2025-06-05 12:19:20,599 - deIdentification.nd_logger - INFO - Inserted batch 16 of 48 for insurance_details.
# 2025-06-05 12:19:26,852 - deIdentification.nd_logger - INFO - Inserted batch 17 of 48 for insurance_details.
# 2025-06-05 12:19:32,858 - deIdentification.nd_logger - INFO - Inserted batch 18 of 48 for insurance_details.
# 2025-06-05 12:19:39,245 - deIdentification.nd_logger - INFO - Inserted batch 19 of 48 for insurance_details.
# 2025-06-05 12:19:45,605 - deIdentification.nd_logger - INFO - Inserted batch 20 of 48 for insurance_details.
# 2025-06-05 12:19:51,436 - deIdentification.nd_logger - INFO - Inserted batch 21 of 48 for insurance_details.
# 2025-06-05 12:19:57,210 - deIdentification.nd_logger - INFO - Inserted batch 22 of 48 for insurance_details.
# 2025-06-05 12:20:02,778 - deIdentification.nd_logger - INFO - Inserted batch 23 of 48 for insurance_details.
# 2025-06-05 12:20:08,873 - deIdentification.nd_logger - INFO - Inserted batch 24 of 48 for insurance_details.
# 2025-06-05 12:20:14,843 - deIdentification.nd_logger - INFO - Inserted batch 25 of 48 for insurance_details.
# 2025-06-05 12:20:20,454 - deIdentification.nd_logger - INFO - Inserted batch 26 of 48 for insurance_details.
# 2025-06-05 12:20:26,241 - deIdentification.nd_logger - INFO - Inserted batch 27 of 48 for insurance_details.
# 2025-06-05 12:20:31,772 - deIdentification.nd_logger - INFO - Inserted batch 28 of 48 for insurance_details.
# 2025-06-05 12:20:37,590 - deIdentification.nd_logger - INFO - Inserted batch 29 of 48 for insurance_details.
# 2025-06-05 12:20:43,535 - deIdentification.nd_logger - INFO - Inserted batch 30 of 48 for insurance_details.
# 2025-06-05 12:20:49,418 - deIdentification.nd_logger - INFO - Inserted batch 31 of 48 for insurance_details.
# 2025-06-05 12:20:55,555 - deIdentification.nd_logger - INFO - Inserted batch 32 of 48 for insurance_details.
# 2025-06-05 12:21:01,277 - deIdentification.nd_logger - INFO - Inserted batch 33 of 48 for insurance_details.
# 2025-06-05 12:21:06,971 - deIdentification.nd_logger - INFO - Inserted batch 34 of 48 for insurance_details.
# 2025-06-05 12:21:12,871 - deIdentification.nd_logger - INFO - Inserted batch 35 of 48 for insurance_details.
# 2025-06-05 12:21:18,678 - deIdentification.nd_logger - INFO - Inserted batch 36 of 48 for insurance_details.
# 2025-06-05 12:21:24,480 - deIdentification.nd_logger - INFO - Inserted batch 37 of 48 for insurance_details.
# 2025-06-05 12:21:30,205 - deIdentification.nd_logger - INFO - Inserted batch 38 of 48 for insurance_details.
# 2025-06-05 12:21:36,473 - deIdentification.nd_logger - INFO - Inserted batch 39 of 48 for insurance_details.
# 2025-06-05 12:21:42,933 - deIdentification.nd_logger - INFO - Inserted batch 40 of 48 for insurance_details.
# 2025-06-05 12:21:48,528 - deIdentification.nd_logger - INFO - Inserted batch 41 of 48 for insurance_details.
# 2025-06-05 12:21:54,533 - deIdentification.nd_logger - INFO - Inserted batch 42 of 48 for insurance_details.
# 2025-06-05 12:22:00,557 - deIdentification.nd_logger - INFO - Inserted batch 43 of 48 for insurance_details.
# 2025-06-05 12:22:06,522 - deIdentification.nd_logger - INFO - Inserted batch 44 of 48 for insurance_details.
# 2025-06-05 12:22:12,473 - deIdentification.nd_logger - INFO - Inserted batch 45 of 48 for insurance_details.
# 2025-06-05 12:22:18,058 - deIdentification.nd_logger - INFO - Inserted batch 46 of 48 for insurance_details.
# 2025-06-05 12:22:23,850 - deIdentification.nd_logger - INFO - Inserted batch 47 of 48 for insurance_details.
# 2025-06-05 12:22:27,858 - deIdentification.nd_logger - INFO - Inserted batch 48 of 48 for insurance_details.
# 2025-06-05 12:22:27,864 - deIdentification.nd_logger - INFO - Data from table insurance_details successfully inserted/updated.

# %%
pii_table_config = {
    "pii_data_table": {
        "primary_column_name": "patient_id",
        "upsert_instead_of_append": True,
        "tables": {
            "users": {
                "primary_col": "uid",
                "other_required_columns": [
                    "uname",
                    "UserType",
                    "upwd",
                    "umobileno",
                    "upagerno",
                    "ufname",
                    "uminitial",
                    "ulname",
                    "uemail",
                    "upaddress",
                    "upcity",
                    "upPhone",
                    "dob",
                    "ssn",
                    "upaddress2",
                    "initials",
                    "ptDob",
                    "upreviousname",
                ],
            },
            "patients": {
                "primary_col": "pid",
                "other_required_columns": [
                    "employername",
                    "employeraddress",
                    "employeraddress2",
                    "employercity",
                    "employerPhone",
                    "insname",
                    "insgroupno",
                    "inssubscriberno",
                    "inscopay",
                    "insname2",
                    "insgroupno2",
                    "inssubscriberno2",
                    "inscopay2",
                    "straddress",
                    "city",
                    "insId",
                    "insId2",
                    "strAddress2",
                    "GrId",
                    "preferred_name",
                ],
            },
        },
    }
}

pii = PIITable(src_db_url, dest_db_url, pii_table_config)
pii.generate_pii_tables()
# Out:
# 2025-06-05 12:22:28,574 - deIdentification.nd_logger - INFO - Existing tables in source DB: 51
# 2025-06-05 12:22:30,699 - deIdentification.nd_logger - INFO - Inserted batch 1 of 1 for pii_data_table.
# 2025-06-05 12:22:30,710 - deIdentification.nd_logger - INFO - Data from table pii_data_table successfully inserted/updated.
# 2025-06-05 12:22:33,043 - deIdentification.nd_logger - INFO - Inserted batch 1 of 1 for pii_data_table.
# 2025-06-05 12:22:33,060 - deIdentification.nd_logger - INFO - Data from table pii_data_table successfully inserted/updated.
