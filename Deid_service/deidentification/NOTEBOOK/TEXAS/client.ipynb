# %%
import os
import django
import sys
import json
# Set up Django environment
sys.path.append(
    "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/"
)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()
import requests
from nd_api.models import Clients, Table, TableMetadata, ClientDataDump
from nd_api.views.utils import register_table_and_generate_analytics
from worker.models import Task, Chain

# /Users/rohitchouhan/Documents/Code/backend/deidentification/deIdentification/nd_api/views/utils.py

# %%
tables = Table.objects.filter(dump__id=1)
tables_info = []
kerror = []
for table in tables:
    try:
        columns = [_d['column_name'] for _d in table.table_details_for_ui['columns_details']]
        tables_info.append({'table_id': table.id, 'table_name': table.table_name, 'columns': columns})
    except KeyError:
        kerror.append(table.table_name)

# %%
kerror
# Out:
# []

# %%
Table.objects.get(table_name="file")
# Out:
# <Table: file - historical_dump - 2898>

# %%
dump_obj = ClientDataDump.objects.last()
dump_obj.source_db_config = {'connection_str': 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/mobiledoc_original'}
dump_obj.save()
# {'connection_str': 'mssql+pymssql://sa:ndADMIN2025@localhost:1433/mobiledoc'}

# %%
# register_table_and_generate_analytics("file", dump_obj, True)

# %%
from nd_api.models import IgnoreRowsDeIdentificaiton

IgnoreRowsDeIdentificaiton.objects.filter(table_name="logdruginteraction").count()
# Out:
# 0

# %%
from nd_api.views.dump_view import add_nd_auto_increment_id_column

# %%
add_nd_auto_increment_id_column(1, ['encounterlog'])
# Out:
# 2025-10-21 19:29:34,629 - deIdentification.nd_logger - INFO - [DONE] encounterlog - nd_auto_increment_id assigned using hashing.
# 2025-10-21 19:29:34,630 - deIdentification.nd_logger - INFO - None
#
# ashing with SQL: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:35<00:00, 35.59s/it]
# [None]

# %%
# Task.objects.all().delete()

# %%
c = Clients.objects.last()

# %%
c.master_db_config = {
    "pii_tables": {
        "pii_data_table": {
            "source_tables": {
                "users": {
                    "required_columns": [
                        {"uid": "patientid"},
                        {"uname": "username"},
                        {"upwd": "password"},
                        {"umobileno": "mobilenumber"},
                        {"upagerno": "pagernumber"},
                        {"ufname": "firstname"},
                        {"uminitial": "initialname"},
                        {"ulname": "lastname"},
                        {"uemail": "email"},
                        {"upaddress": "address"},
                        {"upcity": "city"},
                        {"upPhone": "phonenumber"},
                        {"dob": "dob"},
                        {"ssn": "ssn"},
                        {"upaddress2": "address2"},
                        {"initials": "initials"},
                        {"ptDob": "ptdob"},
                        {"upreviousname": "upreviousname"},
                    ],
                    "primary_column_name": "uid",
                    "primary_column_type": "patientid",
                },
                "patients": {
                    "required_columns": [
                        {"pid": "patientid"},
                        {"employername": "employername"},
                        {"employeraddress": "employeraddress"},
                        {"employeraddress2": "employeraddress2"},
                        {"employercity": "employercity"},
                        {"employerPhone": "employerPhone"},
                        {"insname": "insname"},
                        {"insgroupno": "insgroupno"},
                        {"inssubscriberno": "inssubscriberno"},
                        {"inscopay": "inscopay"},
                        {"pharmacyno": "pharmacyno"},
                        {"insname2": "insname2"},
                        {"insgroupno2": "insgroupno2"},
                        {"inssubscriberno2": "inssubscriberno2"},
                        {"inscopay2": "inscopay2"},
                        {"straddress": "straddress"},
                        {"city": "city"},
                        {"pharmacyFax": "pharmacyFax"},
                        {"insId": "insId"},
                        {"insId2": "insId2"},
                        {"strAddress2": "strAddress2"},
                        {"GrId": "GrId"},
                        {"preferred_name": "preferred_name"},
                    ],
                    "primary_column_name": "pid",
                    "primary_column_type": "patientid",
                },
            },
            "table_columns": [
                "patientid",
                "username",
                "password",
                "mobilenumber",
                "pagernumber",
                "firstname",
                "initialname",
                "lastname",
                "email",
                "address",
                "city",
                "phonenumber",
                "dob",
                "ssn",
                "address2",
                "initials",
                "ptdob",
                "upreviousname",
                "patientid",
                "employername",
                "employeraddress",
                "employeraddress2",
                "employercity",
                "employerPhone",
                "insname",
                "insgroupno",
                "inssubscriberno",
                "inscopay",
                "pharmacyno",
                "insname2",
                "insgroupno2",
                "inssubscriberno2",
                "inscopay2",
                "straddress",
                "city",
                "pharmacyFax",
                "insId",
                "insId2",
                "strAddress2",
                "GrId",
                "preferred_name",
            ],
        },
        "master_insurance_table": {
            "source_tables": {
                "hcfa": {
                    "required_columns": [
                        {"PName": "PName"},
                        {"InsuredName": "InsuredName"},
                        {"InsuredId": "InsuredId"},
                        {"PAddressStreet": "PAddressStreet"},
                        {"PAddressCity": "PAddressCity"},
                        {"InsuredAddStreet": "InsuredAddStreet"},
                        {"InsuredAddCity": "InsuredAddCity"},
                        {"NameRef": "NameRef"},
                        {"SSN": "SSN"},
                        {"EmpOrSchoolName": "EmpOrSchoolName"},
                        {"InsurancePlan": "InsurancePlan"},
                        {"OtherInsuredName": "OtherInsuredName"},
                        {"OtherEmpName": "OtherEmpName"},
                        {"OtherInsuranceName": "OtherInsuranceName"},
                        {"PayorName1": "PayorName1"},
                        {"PayorName2": "PayorName2"},
                        {"PayorName3": "PayorName3"},
                        {"PayorAddress11": "PayorAddress11"},
                        {"PayorAddress12": "PayorAddress12"},
                        {"PayorAddress13": "PayorAddress13"},
                        {"PayorAddress21": "PayorAddress21"},
                        {"PayorAddress22": "PayorAddress22"},
                        {"PayorAddress23": "PayorAddress23"},
                        {"PayorCity1": "PayorCity1"},
                        {"PayorZip1": "PayorZip1"},
                        {"PayorCity2": "PayorCity2"},
                        {"PayorZip2": "PayorZip2"},
                        {"PayorCity3": "PayorCity3"},
                        {"PayorZip3": "PayorZip3"},
                        {"pid": "patientid"},
                        
                    ],
                    "primary_column_name": "pid",
                    "primary_column_type": "patientid",
                }
            },
            "table_columns": [
                "PayorName2",
                "OtherInsuredName",
                "OtherEmpName",
                "PayorAddress13",
                "PayorAddress12",
                "PayorCity2",
                "InsuredName",
                "PayorAddress22",
                "OtherInsuranceName",
                "PayorZip1",
                "InsurancePlan",
                "InsuredId",
                "PayorZip2",
                "PayorAddress11",
                "EmpOrSchoolName",
                "PAddressCity",
                "NameRef",
                "encounter_id",
                "PayorCity3",
                "PayorAddress21",
                "PayorCity1",
                "PayorName1",
                "InsuredAddCity",
                "PayorZip3",
                "PAddressStreet",
                "SSN",
                "PName",
                "PayorName3",
                "PayorAddress23",
                "InsuredAddStreet",
                "patientid"
            ],
        },
    }
}


c.save()

# %%
c = Cli
