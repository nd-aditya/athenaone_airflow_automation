# %%
import pandas as pd

phi = pd.read_csv('mind_full_phi.csv')
emd = pd.read_csv('emd_table_list.csv')
phi.shape, emd.shape
# Out:
# ((19990, 7), (53, 1))

# %%
tables = emd['TABLE_NAME'].to_list()
len(tables)
# Out:
# 53

# %%
phi = phi[phi['TABLE_NAME'].isin(tables)]
phi.shape
# Out:
# (720, 7)

# %%
phi['TABLE_NAME'].nunique()
# Out:
# 53

# %%
phi.to_csv('mind_emd_phi.csv', index=False)
