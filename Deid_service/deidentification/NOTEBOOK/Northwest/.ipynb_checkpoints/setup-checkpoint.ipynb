# %%
import os
import django
import sys
# Set up Django environment
sys.path.append('/Users/neurodiscoveryai/Desktop/Soorykant/deidentification/deIdentification/')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from nd_api.views.de_identification_task import create_deidentification_task
from nd_api.models import DbDetailsModel, TableDetailsModel
from worker.models import Task, Chain
from django.contrib.auth.models import User
from keycloakauth.rolemodel import RoleModel, get_default_permissions
from nd_scripts.create_account import create_account
from nd_api.views.db_views import create_stats_generation_tasks
from core.process.main import start_de_identification_for_table
from nd_api.views.de_identification_task import create_deidentification_task
from nd_api.views.db_views import run_stats_generation_task

def clean_db():
    RoleModel.objects.all().delete()
    User.objects.all().delete()
    DbDetailsModel.objects.all().delete()
    Chain.objects.all().delete()

# %%
db, _ = DbDetailsModel.objects.get_or_create(db_name="northwest_metadata")

# %%
db.source_db_config = {
    "connection_str": 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/mobiledoc'
}
db.destination_db_config = {
    "connection_str": 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/deidentified'
}
db.run_config["mapping_db_config"] = {
    "connection_str": "mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/mapping",
    "inhouse_mapping_table": False,
}

db.save()

# %%
db.run_config['pii_config'] = {'mask': {'users_uname': {'masking_value': '((PatientDetail))'},
  'users_upwd': {'masking_value': '((PatientDetail))'},
  'users_umobileno': {'masking_value': '((PatientPhone))'},
  'users_upagerno': {'masking_value': '((PatientPhone))'},
  'users_ufname': {'masking_value': '((PatientName))'},
  'users_uminitial': {'masking_value': '((PatientName))'},
  'users_ulname': {'masking_value': '((PatientName))'},
  'users_uemail': {'masking_value': '((PatientEmail))'},
  'users_upaddress': {'masking_value': '((PatientAddress))'},
  'users_upcity': {'masking_value': '((PatientCity))'},
  'users_upPhone': {'masking_value': '((PatientPhone))'},
  'users_ssn': {'masking_value': '((PatientSSN))'},
  'users_upaddress2': {'masking_value': '((PatientAddress))'},
  'users_initials': {'masking_value': '((PatientName))'},
  'users_upreviousname': {'masking_value': '((PatientName))'},
  'patients_employername': {'masking_value': '((EmployerName))'},
  'patients_employeraddress': {'masking_value': '((EmployerDetails))'},
  'patients_employeraddress2': {'masking_value': '((EmployerDetails))'},
  'patients_employercity': {'masking_value': '((EmployerDetails))'},
  'patients_employerPhone': {'masking_value': '((EmployerDetails))'},
  'patients_insname': {'masking_value': '((InsuranceDetails))'},
  'patients_insgroupno': {'masking_value': '((InsuranceDetails))'},
  'patients_inssubscriberno': {'masking_value': '((InsuranceDetails))'},
  'patients_inscopay': {'masking_value': '((InsuranceDetails))'},
  'patients_insname2': {'masking_value': '((InsuranceDetails))'},
  'patients_insgroupno2': {'masking_value': '((InsuranceDetails))'},
  'patients_inssubscriberno2': {'masking_value': '((InsuranceDetails))'},
  'patients_inscopay2': {'masking_value': '((InsuranceDetails))'},
  'patients_straddress': {'masking_value': '((Address))'},
  'patients_city': {'masking_value': '((City))'},
  'patients_insId': {'masking_value': '((InsuranceDetails))'},
  'patients_insId2': {'masking_value': '((InsuranceDetails))'},
  'patients_strAddress2': {'masking_value': '((Address))'},
  'patients_GrId': {'masking_value': '((PatientDetail))'},
  'patients_preferred_name': {'masking_value': '((PatientName))'}},
 'dob': {'users_dob': {'masking_value': '((PatientDOB))'},
  'users_ptDob': {'masking_value': '((PatientDOB))'}},
 'regex': {'ssn': {'regex': ['\\b\\d{3}[- ]\\d{2}[- ]\\d{4}\\b'],
   'masking_value': '((SSN))',
   'processing_func': None},
  'umobileno': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
    '\\b\\d{3}-\\d{3}-\\d{4}\\b',
    '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
    '\\b\\d{3} \\d{3} \\d{4}\\b'],
   'masking_value': '((PHONENUMBER))',
   'processing_func': None},
  'upagerno': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
    '\\b\\d{3}-\\d{3}-\\d{4}\\b',
    '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
    '\\b\\d{3} \\d{3} \\d{4}\\b'],
   'masking_value': '((PHONENUMBER))',
   'processing_func': None},
  'upPhone': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
    '\\b\\d{3}-\\d{3}-\\d{4}\\b',
    '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
    '\\b\\d{3} \\d{3} \\d{4}\\b'],
   'masking_value': '((PHONENUMBER))',
   'processing_func': None},
  'employerPhone': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
    '\\b\\d{3}-\\d{3}-\\d{4}\\b',
    '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
    '\\b\\d{3} \\d{3} \\d{4}\\b'],
   'masking_value': '((PHONENUMBER))',
   'processing_func': None},
  'uemail': {'regex': ['\\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\\.[A-Za-z]{2,}\\b'],
   'masking_value': '((EMAIL))',
   'processing_func': None}},
 'combine': {'patientfullname': {'regex': None,
   'combine': ['ufname', 'uminitial', 'ulname'],
   'masking_value': '((PATIENTNAME))',
   'processing_func': None}},
 'replace_value': [{'old_value': 'Northwest',
   'new_value': '((FACILITYNAME))'}]}

db.save()

# %%
db.run_config['pii_db_config'] = {'master_connection_str': 'mysql+pymysql://nd_read:ndREAD%402025@localhost:3306/master',
 'insurance_connection_str': 'mysql+pymysql://nd_read:ndREAD%402025@localhost:3306/master',
 'insurance_metadata': {'hcfa_PName': {'mask_value': '((PatientName))',
   'min_length': 2},
  'hcfa_InsuredName': {'mask_value': '((PatientName))', 'min_length': 2},
  'hcfa_InsuredId': {'mask_value': '((InsuranceID))', 'min_length': 2},
  'hcfa_PAddressStreet': {'mask_value': '((PatientAddress))', 'min_length': 2},
  'hcfa_PAddressCity': {'mask_value': '((PatientCity))', 'min_length': 2},
  'hcfa_InsuredAddStreet': {'mask_value': '((PatientAddress))',
   'min_length': 2},
  'hcfa_InsuredAddCity': {'mask_value': '((PatientCity))', 'min_length': 2},
  'hcfa_NameRef': {'mask_value': '((PatientName))', 'min_length': 2},
  'hcfa_SSN': {'mask_value': '((PatientSSN))', 'min_length': 2},
  'hcfa_EmpOrSchoolName': {'mask_value': '((EmployerDetails))',
   'min_length': 2},
  'hcfa_InsurancePlan': {'mask_value': '((InsuranceDetails))',
   'min_length': 2},
  'hcfa_OtherInsuredName': {'mask_value': '((PatientName))', 'min_length': 2},
  'hcfa_OtherEmpName': {'mask_value': '((EmployerDetails))', 'min_length': 2},
  'hcfa_OtherInsuranceName': {'mask_value': '((InsuranceDetails))',
   'min_length': 2},
  'hcfa_PayorName1': {'mask_value': '((PayorName))', 'min_length': 2},
  'hcfa_PayorName2': {'mask_value': '((PayorName))', 'min_length': 2},
  'hcfa_PayorName3': {'mask_value': '((PayorName))', 'min_length': 2},
  'hcfa_PayorAddress11': {'mask_value': '((PayorAddress))', 'min_length': 2},
  'hcfa_PayorAddress12': {'mask_value': '((PayorAddress))', 'min_length': 2},
  'hcfa_PayorAddress13': {'mask_value': '((PayorAddress))', 'min_length': 2},
  'hcfa_PayorAddress21': {'mask_value': '((PayorAddress))', 'min_length': 2},
  'hcfa_PayorAddress22': {'mask_value': '((PayorAddress))', 'min_length': 2},
  'hcfa_PayorAddress23': {'mask_value': '((PayorAddress))', 'min_length': 2},
  'hcfa_PayorCity1': {'mask_value': '((PayorCity))', 'min_length': 2},
  'hcfa_PayorZip1': {'mask_value': '((PayorZip))', 'min_length': 2},
  'hcfa_PayorCity2': {'mask_value': '((PayorCity))', 'min_length': 2},
  'hcfa_PayorZip2': {'mask_value': '((PayorZip))', 'min_length': 2},
  'hcfa_PayorCity3': {'mask_value': '((PayorCity))', 'min_length': 2},
  'hcfa_PayorZip3': {'mask_value': '((PayorZip))', 'min_length': 2}}}

db.save()

# %%
# run_stats_generation_task(db.id)

# %%
db.id
# Out:
# 1

# %%
TableDetailsModel.objects.create(db=db, table_name="progressnotes_decryptfinal")
# Out:
# <TableDetailsModel: progressnotes_decryptfinal - northwest_metadata - 8130>

# %%
oldtb = TableDetailsModel.objects.get(table_name="progressnotes")
newtb = TableDetailsModel.objects.get(db=db, table_name="progressnotes_decryptfinal")
newtb.rows_count = oldtb.rows_count
newtb.table_details_for_ui = oldtb.table_details_for_ui

newtb.save()

# %%
db.__dict__
# Out:
# {'_state': <django.db.models.base.ModelState at 0x13e7c9b80>,
#  'id': 1,
#  'db_name': 'northwest_metadata',
#  'source_db_config': {'connection_str': 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/mobiledoc'},
#  'destination_db_config': {'connection_str': 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/deidentified'},
#  'run_config': {'pii_config': {'mask': {'users_uname': {'masking_value': '((PatientDetail))'},
#     'users_upwd': {'masking_value': '((PatientDetail))'},
#     'users_umobileno': {'masking_value': '((PatientPhone))'},
#     'users_upagerno': {'masking_value': '((PatientPhone))'},
#     'users_ufname': {'masking_value': '((PatientName))'},
#     'users_uminitial': {'masking_value': '((PatientName))'},
#     'users_ulname': {'masking_value': '((PatientName))'},
#     'users_uemail': {'masking_value': '((PatientEmail))'},
#     'users_upaddress': {'masking_value': '((PatientAddress))'},
#     'users_upcity': {'masking_value': '((PatientCity))'},
#     'users_upPhone': {'masking_value': '((PatientPhone))'},
#     'users_ssn': {'masking_value': '((PatientSSN))'},
#     'users_upaddress2': {'masking_value': '((PatientAddress))'},
#     'users_initials': {'masking_value': '((PatientName))'},
#     'users_upreviousname': {'masking_value': '((PatientName))'},
#     'patients_employername': {'masking_value': '((EmployerName))'},
#     'patients_employeraddress': {'masking_value': '((EmployerDetails))'},
#     'patients_employeraddress2': {'masking_value': '((EmployerDetails))'},
#     'patients_employercity': {'masking_value': '((EmployerDetails))'},
#     'patients_employerPhone': {'masking_value': '((EmployerDetails))'},
#     'patients_insname': {'masking_value': '((InsuranceDetails))'},
#     'patients_insgroupno': {'masking_value': '((InsuranceDetails))'},
#     'patients_inssubscriberno': {'masking_value': '((InsuranceDetails))'},
#     'patients_inscopay': {'masking_value': '((InsuranceDetails))'},
#     'patients_insname2': {'masking_value': '((InsuranceDetails))'},
#     'patients_insgroupno2': {'masking_value': '((InsuranceDetails))'},
#     'patients_inssubscriberno2': {'masking_value': '((InsuranceDetails))'},
#     'patients_inscopay2': {'masking_value': '((InsuranceDetails))'},
#     'patients_straddress': {'masking_value': '((Address))'},
#     'patients_city': {'masking_value': '((City))'},
#     'patients_insId': {'masking_value': '((InsuranceDetails))'},
#     'patients_insId2': {'masking_value': '((InsuranceDetails))'},
#     'patients_strAddress2': {'masking_value': '((Address))'},
#     'patients_GrId': {'masking_value': '((PatientDetail))'},
#     'patients_preferred_name': {'masking_value': '((PatientName))'}},
#    'dob': {'users_dob': {'masking_value': '((PatientDOB))'},
#     'users_ptDob': {'masking_value': '((PatientDOB))'}},
#    'regex': {'ssn': {'regex': ['\\b\\d{3}[- ]\\d{2}[- ]\\d{4}\\b'],
#      'masking_value': '((SSN))',
#      'processing_func': None},
#     'umobileno': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
#       '\\b\\d{3}-\\d{3}-\\d{4}\\b',
#       '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
#       '\\b\\d{3} \\d{3} \\d{4}\\b'],
#      'masking_value': '((PHONENUMBER))',
#      'processing_func': None},
#     'upagerno': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
#       '\\b\\d{3}-\\d{3}-\\d{4}\\b',
#       '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
#       '\\b\\d{3} \\d{3} \\d{4}\\b'],
#      'masking_value': '((PHONENUMBER))',
#      'processing_func': None},
#     'upPhone': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
#       '\\b\\d{3}-\\d{3}-\\d{4}\\b',
#       '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
#       '\\b\\d{3} \\d{3} \\d{4}\\b'],
#      'masking_value': '((PHONENUMBER))',
#      'processing_func': None},
#     'employerPhone': {'regex': ['\\(\\d{3}\\)\\s*\\d{3}-\\d{4}',
#       '\\b\\d{3}-\\d{3}-\\d{4}\\b',
#       '\\+\\d{1,3}\\s\\d{1,4}[- ]\\d{3}[- ]\\d{4}\\b',
#       '\\b\\d{3} \\d{3} \\d{4}\\b'],
#      'masking_value': '((PHONENUMBER))',
#      'processing_func': None},
#     'uemail': {'regex': ['\\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\\.[A-Za-z]{2,}\\b'],
#      'masking_value': '((EMAIL))',
#      'processing_func': None}},
#    'combine': {'patientfullname': {'regex': None,
#      'combine': ['ufname', 'uminitial', 'ulname'],
#      'masking_value': '((PATIENTNAME))',
#      'processing_func': None}},
#    'replace_value': [{'old_value': 'Northwest',
#      'new_value': '((FACILITYNAME))'}]},
#   'pii_db_config': {'master_connection_str': 'mysql+pymysql://nd_read:ndREAD%402025@localhost:3306/master',
#    'insurance_connection_str': 'mysql+pymysql://nd_read:ndREAD%402025@localhost:3306/master',
#    'insurance_metadata': {'hcfa_PName': {'mask_value': '((PatientName))',
#      'min_length': 2},
#     'hcfa_InsuredName': {'mask_value': '((PatientName))', 'min_length': 2},
#     'hcfa_InsuredId': {'mask_value': '((InsuranceID))', 'min_length': 2},
#     'hcfa_PAddressStreet': {'mask_value': '((PatientAddress))',
#      'min_length': 2},
#     'hcfa_PAddressCity': {'mask_value': '((PatientCity))', 'min_length': 2},
#     'hcfa_InsuredAddStreet': {'mask_value': '((PatientAddress))',
#      'min_length': 2},
#     'hcfa_InsuredAddCity': {'mask_value': '((PatientCity))', 'min_length': 2},
#     'hcfa_NameRef': {'mask_value': '((PatientName))', 'min_length': 2},
#     'hcfa_SSN': {'mask_value': '((PatientSSN))', 'min_length': 2},
#     'hcfa_EmpOrSchoolName': {'mask_value': '((EmployerDetails))',
#      'min_length': 2},
#     'hcfa_InsurancePlan': {'mask_value': '((InsuranceDetails))',
#      'min_length': 2},
#     'hcfa_OtherInsuredName': {'mask_value': '((PatientName))',
#      'min_length': 2},
#     'hcfa_OtherEmpName': {'mask_value': '((EmployerDetails))',
#      'min_length': 2},
#     'hcfa_OtherInsuranceName': {'mask_value': '((InsuranceDetails))',
#      'min_length': 2},
#     'hcfa_PayorName1': {'mask_value': '((PayorName))', 'min_length': 2},
#     'hcfa_PayorName2': {'mask_value': '((PayorName))', 'min_length': 2},
#     'hcfa_PayorName3': {'mask_value': '((PayorName))', 'min_length': 2},
#     'hcfa_PayorAddress11': {'mask_value': '((PayorAddress))', 'min_length': 2},
#     'hcfa_PayorAddress12': {'mask_value': '((PayorAddress))', 'min_length': 2},
#     'hcfa_PayorAddress13': {'mask_value': '((PayorAddress))', 'min_length': 2},
#     'hcfa_PayorAddress21': {'mask_value': '((PayorAddress))', 'min_length': 2},
#     'hcfa_PayorAddress22': {'mask_value': '((PayorAddress))', 'min_length': 2},
#     'hcfa_PayorAddress23': {'mask_value': '((PayorAddress))', 'min_length': 2},
#     'hcfa_PayorCity1': {'mask_value': '((PayorCity))', 'min_length': 2},
#     'hcfa_PayorZip1': {'mask_value': '((PayorZip))', 'min_length': 2},
#     'hcfa_PayorCity2': {'mask_value': '((PayorCity))', 'min_length': 2},
#     'hcfa_PayorZip2': {'mask_value': '((PayorZip))', 'min_length': 2},
#     'hcfa_PayorCity3': {'mask_value': '((PayorCity))', 'min_length': 2},
#     'hcfa_PayorZip3': {'mask_value': '((PayorZip))', 'min_length': 2}}},
#   'mapping_db_config': {'connection_str': 'mysql+pymysql://ndadmin:ndADMIN%402025@localhost:3306/mapping',
#    'inhouse_mapping_table': False}},
#  'stats_generated_status': 2,
#  'db_stats': {'graphs': {'rows_count_distribution': {'less_than_1000': 7323,
#     'greater_than_1000000': 114,
#     'between_1000_and_10000': 259,
#     'between_10000_and_100000': 212,
#     'between_100000_and_1000000': 221}},
#   'tables_stats': {'rx': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'afp': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'coc': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 2},
#    'enc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2302468},
#    'hpi': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1109961},
#    'icd': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 92608},
#    'log': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 7013219},
#    'pas': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'rvu': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 119787},
#    'tag': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 9},
#    'ahca': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'chdp': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'file': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'golf': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'hcfa': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 42762},
#    'pqri': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 27},
#    'race': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 7},
#    'tags': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 8834},
#    'task': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 1},
#    'bpage': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 68},
#    'chart': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 103},
#    'encex': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 611722},
#    'faxau': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 3},
#    'files': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'form9': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'hcpcs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 4006},
#    'icd_9': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 326262},
#    'idmap': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ik_wl': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 6},
#    'items': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 375946},
#    'notes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 903012},
#    'p_dsi': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 15},
#    'roles': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'telcc': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'users': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 266033},
#    'wstat': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 92},
#    'wtage': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 436},
#    'xrays': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'annual': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ascmap': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 35},
#    'bmiage': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 436},
#    'census': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'config': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 5},
#    'county': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3235},
#    'cptcvx': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 88},
#    'cqwenc': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'dockpn': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ebinfo': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 35},
#    'enclog': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 1},
#    'family': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1826099},
#    'gender': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 4},
#    'groups': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'kidmed': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'labels': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 8},
#    'panels': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'payers': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'phrlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 50680},
#    'pmlist': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 4},
#    'proctp': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'review': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 11440462},
#    'rvucms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 33637},
#    'snomed': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 45008},
#    'social': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 993859},
#    'sports': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'states': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 477},
#    'tagmap': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 9},
#    'telenc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 883380},
#    'triage': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'trtemp': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'vitals': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 6910167},
#    'x12dtp': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 5412952},
#    'x12ebs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 19266365},
#    'x12hsd': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'x12msg': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'x12per': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'acg_rub': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'actions': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ai_lead': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'auc_log': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'bh_logs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'billing': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'bplevel': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 476},
#    'ccmrlog': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'cd_goal': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'cpt_cvx': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 129},
#    'doctors': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 9354},
#    'drugref': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 598},
#    'ebotime': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 86399},
#    'ecwdocs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'edi_pos': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 52},
#    'edi_tos': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 229},
#    'ehi_log': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ehi_map': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1085},
#    'emcoder': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 764},
#    'erajobs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 2},
#    'evakeys': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 6},
#    'faxlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 726798},
#    'form_tc': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'golftee': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'hearing': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 2},
#    'hotkeys': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1723},
#    'icd9gem': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 24860},
#    'ik_auth': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1133},
#    'immlist': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 1},
#    'intlist': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'labdata': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 667221},
#    'lablist': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 94},
#    'logtemp': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'message': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 111774},
#    'nhxjobs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 9},
#    'obf_edd': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'obf_lab': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ooologs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 5},
#    'package': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 5},
#    'pgm_kpi': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 11},
#    'picture': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'pmcodes': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 26},
#    'pos_map': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 28},
#    'prtxids': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'psacicd': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 1},
#    'refunds': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 568},
#    'rel_map': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 4},
#    'reports': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 2},
#    'ri_labs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ruleset': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'rvulogs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'siginfo': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'statage': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 436},
#    'summary': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'sws_log': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'tos_map': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'udstemp': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ufgdefs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 1},
#    'usrlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 487902},
#    'vhsetup': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'x12_cfg': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 3},
#    'x12refs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 486364},
#    'abncodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4463},
#    'asc_role': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 26},
#    'autocode': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 6},
#    'beerlist': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'bh_group': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'bh_roles': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'bumplist': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 609},
#    'cachedrx': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'calltype': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'careplan': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'cascodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 392},
#    'cd_group': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'claim277': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'cldetail': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'cmd_card': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'contacts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 39347},
#    'cp_score': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'cptcodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 8262},
#    'csv_temp': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'customrx': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 419},
#    'cworders': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'cytology': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'dea_logs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 36},
#    'diagrams': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'dmportal': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3120},
#    'document': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2695359},
#    'drawings': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'dxalerts': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ebo_info': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 4},
#    'ecwitems': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 114},
#    'ecwnotes': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'edi_ub92': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 659135},
#    'employer': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 74},
#    'enc_sync': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1693056},
#    'eptstmts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 521045},
#    'est_rule': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 6},
#    'form_org': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'freecare': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'hcageinf': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 76},
#    'icd10gem': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 81593},
#    'immcodes': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'implants': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ins_list': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'insaging': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'intcodes': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ip_items': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'itemkeys': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4010},
#    'keywords': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 5738},
#    'lab_sync': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 163189},
#    'labalias': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 1},
#    'labcodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 67352},
#    'lawfirms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 13},
#    'location': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'logstore': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'lotdates': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 2},
#    'lsm_team': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'mcaid_al': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'mcaid_co': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'mcaid_il': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'mcaid_ny': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'mcaid_or': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'mcare_il': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 56},
#    'mentions': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 38},
#    'mergeenc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 506},
#    'misclogs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'msgtypes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 10},
#    'mu_codes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 111},
#    'obf_tri1': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'obf_tri2': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'obf_tri3': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'packages': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'pama_cpt': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 273},
#    'patients': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 256098},
#    'pcf_logs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'pharmacy': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4458},
#    'pm_rules': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 2},
#    'pm_users': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'pmorders': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 313576},
#    'practice': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ptagmsgs': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'ptlastov': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 368},
#    'ptorders': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'qrda_enc': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'qrsitems': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'questaoe': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 9977},
#    'rcmusers': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'recvrcfg': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 3},
#    'referral': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 58093},
#    'rulescpt': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 35},
#    'rulesins': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 442},
#    'rxalerts': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'salestax': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'schedule': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'shopcart': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'stmtsgro': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'structia': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'supplier': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'sws_sets': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'tasklogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 80227},
#    'tcny_den': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 594},
#    'tcny_num': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 527},
#    'template': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 24462},
#    'uds_pool': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'udstemp1': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'visionrx': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'voiceenc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 320},
#    'wstopics': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 0},
#    'wtageinf': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 76},
#    'wtleninf': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 120},
#    'x270_cfg': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 35},
#    'x278_cfg': {'size': '1 GB', 'fks_to': [], 'fks_from': [], 'rows_count': 1},
#    'zipcodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2931},
#    'adminlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 26},
#    'ages_seen': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1350},
#    'alertdata': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 18751},
#    'allergies': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 368977},
#    'appntlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'appt_misc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_gases': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_notes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'auth_user': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'batchtemp': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'bh_phases': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'bloodlead': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'bodysites': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 25825},
#    'capconfig': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ccm_batch': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ccmr_data': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ccmr_logs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cdss_labs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'cdss_logs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 27440},
#    'chatfiles': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'clproduct': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cmd_image': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cmd_query': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf0': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf1': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf2': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf3': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf4': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf5': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf6': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf7': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf8': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cms_cclf9': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cpc_query': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cptfeesch': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 150273},
#    'cqm_items': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 7},
#    'cqm_query': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4512},
#    'depttypes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'diagnosis': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1895734},
#    'drcmusers': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ecwloguri': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 43},
#    'ecwqm_url': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'edi_837k3': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'edi_forms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'emaillogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4312},
#    'enc_vital': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 130731},
#    'encclaims': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'encdetail': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 100843},
#    'encounter': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'enctaxids': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'eradetail': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 65639},
#    'eraheader': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 64488},
#    'ethnicity': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 45},
#    'extension': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 91},
#    'familyicd': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 8},
#    'faxaulogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 13944},
#    'faxserver': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2},
#    'feeschmap': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2},
#    'fluclinic': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'form_copy': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'form_medd': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'form_note': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'formulary': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ftpconfig': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'hashcodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 31881},
#    'hcc_query': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 34},
#    'hi_config': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 15},
#    'hl7config': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'icdcptmap': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'icdportal': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'immintlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'immorders': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'insgroups': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 5},
#    'insurance': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1760},
#    'ipaddress': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'itemparam': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 569},
#    'kiosktask': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'kreadings': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'lab_rules': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 10},
#    'labcptmap': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 166},
#    'labdatacc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 9},
#    'labdataex': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 295634},
#    'laborders': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 50},
#    'labranges': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'labresult': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'lenageinf': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 76},
#    'locations': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'log_table': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 5},
#    'logfilter': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1247},
#    'main_menu': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 682},
#    'massform5': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'menu_list': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 27},
#    'mergelogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1783},
#    'messenger': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 491},
#    'milestone': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'msgdetail': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 165438},
#    'mvx_codes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 120},
#    'neaconfig': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'nhxmpiemr': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 981},
#    'nhxtelenc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1045},
#    'notes_tag': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 10},
#    'nt_mapper': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 659},
#    'oa_enc_fu': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 204718},
#    'obhistory': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 20},
#    'oldrxmain': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4655120},
#    'optreason': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4},
#    'ordersets': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 500},
#    'packagedi': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'packagerx': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'pay2prmap': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'pcf_notes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'pdmp_logs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 426},
#    'perfstats': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'perioexam': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'pm_levels': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2},
#    'pmcharges': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'pmgateway': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'pn_mapper': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'portalbox': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'printlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1350431},
#    'qm_alerts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'qrda_comm': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'qrda_diag': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'qrsdetail': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'rcm_roles': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'reviewlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1615660},
#    'ri_vitals': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'rwformlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'sequences': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'smartform': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 427},
#    'smartnote': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'soapitems': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 47},
#    'statefips': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'structcqw': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'structhpi': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 329},
#    'structsws': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'structtoc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'supdetail': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'tblwebmsg': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 186136},
#    'tcm_notes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'tcny_temp': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'telemetry': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'timezones': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 16},
#    'todo_list': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'todo_type': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 13},
#    'tranx_rpt': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'uds_codes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 126},
#    'uifielddb': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 59921},
#    'usertypes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'validcpts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 20116},
#    'vfc_codes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 13},
#    'vitalslog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 266035},
#    'workhours': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 26858},
#    'abnoptions': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'acg_config': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4},
#    'acg_mm_acg': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'adminsites': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ai_leadlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ai_product': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 33},
#    'annualdata': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'aoedetails': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 70},
#    'aoeoptions': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 10015},
#    'appservers': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'apptblocks': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 105499},
#    'apptbuffer': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 69824},
#    'asc_opnote': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'asc_pnlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_vitals': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ascmap_log': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'atriausers': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'bb_batches': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'bb_kpi_raw': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'bh_outcome': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cachedlabs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'callstatus': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'caregroups': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'case_types': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4},
#    'ccm_alerts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 9},
#    'ccm_status': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'cd_problem': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cdss_codes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 236},
#    'cdss_query': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 12},
#    'celldynmap': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'chdp_setup': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'checkinout': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'chs_config': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'compoundrx': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'config_dea': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 43},
#    'cost_files': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cpc_pt_emp': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cpc_siteid': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cptcvx_cdc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 268},
#    'cqm_lookup': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 154103},
#    'cqw_header': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'creditcard': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 5},
#    'cspreports': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cwusermsgs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'dcf_encpts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2263},
#    'dcf_ptdemo': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 212708},
#    'deahistory': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 124},
#    'definition': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'dental_psr': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'disclaimer': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'dj_ctl_cms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'dw_dim_psm': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 370},
#    'dw_dim_sql': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1099},
#    'ebo_gl_log': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ebocaldate': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 73415},
#    'ecgreports': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ecwsynclog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
# ...
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4},
#    'allergy_form': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'allergy_test': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'allergytypes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4},
#    'anesruleprov': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'apptblocklog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 65678},
#    'apptreminder': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_comments': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_ioorders': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_orintrop': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_orpostop': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'asc_ptorders': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'autocodecond': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 35},
#    'autocodeitem': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 24},
#    'backuprform2': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 14},
#    'backuprwform': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 134},
#    'bfe_document': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 244},
#    'bh_reviewlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'bh_signature': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'billingedits': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 23},
#    'birth_vitals': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'blbs_payorid': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 17},
#    'callcategory': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'careplan_log': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cascodes_del': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 390},
#    'cascodes_old': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 253},
#    'case_details': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 626},
#    'ccmr_bhnotes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ccmr_riskmap': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ccmr_subitem': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cd_behaviour': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cd_objective': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cdb_file_log': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'celldynitems': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'chadisstatus': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'chartoptions': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 118},
#    'chartscreens': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 19},
#    'check_status': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cmd_category': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cmd_template': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cmpgn_survey': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'coc_contacts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'configediaa0': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'corpauthlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 315},
#    'countrycodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 244},
#    'cp_temp_prob': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cp_temp_ques': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cpo_services': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cptcode_base': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 11992},
#    'cptfeeschlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 272118},
#    'cqm_measures': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 135},
#    'cqm_pcfitems': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 16},
#    'cqm_programs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cqw_response': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cr_providers': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'cre_category': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 11},
#    'culturecodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'dental_print': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'deviceconfig': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'devicemaster': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 7},
#    'dl_cube_psms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 62157},
#    'docidtyperef': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 62},
#    'document_old': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'dosechecklog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'downloadlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 7},
#    'dslenage0to3': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 74},
#    'dswtage2to18': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 98},
#    'dx_providers': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ebo_logstore': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'eboarbalance': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ebousersinfo': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ecqm_filters': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 15},
#    'ecw_commimms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ecw_pub_keys': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2},
#    'ecwaccesslog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2769},
#    'ecwprintlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 37660},
#    'edi_box17cpt': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'edi_cptcodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 31062},
#    'edi_dfr_info': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 2},
#    'edi_fingroup': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 10},
#    'edi_groupnpi': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'edi_icdcodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 93378},
#    'edi_payments': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'edi_ppoindex': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 13},
#    'edi_symptoms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'eicrccdbatch': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'emar_medtype': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 10},
#    'emessagelogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'empi_version': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'empiallicd9s': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'empibatchlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'empisettings': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'emrurlmaster': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 20},
#    'enc_utctimes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 58654},
#    'encaddendums': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 13021},
#    'encdashboard': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'encounterlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3866398},
#    'encreference': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 6},
#    'encupdatelog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'eobscan_logs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'epay_emv_log': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'epcs_reports': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 456},
#    'eptstmtsbkup': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'eptstmtstemp': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 791734},
#    'est_cptgroup': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'est_discount': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 8},
#    'est_rule_pos': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4},
#    'ethnicity_az': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_ga': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_id': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_in': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_la': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_ny': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_wa': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_wv': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ethnicity_wy': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'examdefaults': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 14},
#    'facilitylogo': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'facimmexport': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'familydetail': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 414606},
#    'faxai_config': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 10},
#    'faxinboxlogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4058},
#    'fhirauditlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'filescaninfo': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'fileschedule': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'form_product': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ftpcommunity': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'globalalerts': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 87},
#    'groupdetails': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1635},
#    'groupmembers': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'h2h_sms_logs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'hardresetpwd': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 17},
#    'hcc_requests': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'hi_payor_mtm': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'hi_payor_tcm': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'hl7ptmpidata': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'icd10cm_desc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 97584},
#    'icd_synonyms': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'icdriskvalue': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ihe_document': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 94257},
#    'ik_auth_type': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 15},
#    'immmergelogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'immseriescvx': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 17},
#    'implantslogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'importcdtlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'intcodes_enc': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'interfacexml': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 4},
#    'interopbatch': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 332026},
#    'inventory_md': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'ip_ui_column': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 22},
#    'ip_ui_module': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'ip_ui_screen': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'ip_user_pref': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'kafka_topics': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 3},
#    'kioskodalogs': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'kioskreports': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'kiosksetting': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'kioskvendors': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'labletterlog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'locatorcodes': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'mcmp_patient': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'methadoneprg': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'mfnupdatelog': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    'midmarkitems': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 1},
#    'movietickets': {'size': '1 GB',
#     'fks_to': [],
#     'fks_from': [],
#     'rows_count': 0},
#    ...}},
#  'is_phi_marking_locked': False}
