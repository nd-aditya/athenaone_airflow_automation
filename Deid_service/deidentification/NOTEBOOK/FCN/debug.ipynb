# %%
import os
import django
import sys
import json
# Set up Django environment
sys.path.append(
    "/Users/fcn/Documents/DEPORTAL/deidentification/deIdentification"
)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()
import requests
from nd_api.models import Clients, Table, TableMetadata, ClientDataDump
from nd_api.views.utils import register_table_and_generate_analytics

# /Users/rohitchouhan/Documents/Code/backend/deidentification/deIdentification/nd_api/views/utils.py

# %%
cd = ClientDataDump.objects.last()

# %%
cd.source_db_config = {'connection_str': 'mssql+pymssql://ndadmin:ndADMIN%402025@172.20.103.10:57546/db_fineco_demo'}
cd.save()

# %%
c = Clients.objects.last()

# %%
c.master_db_config = {
    "pii_schema_name": "master_prod",
    "pii_tables": {
        "pii_data_table": {
            "source_tables": {
                "users": {
                    "required_columns": [
                        {
                            "uname": "username"
                        },
                        {
                            "upwd": "password"
                        },
                        {
                            "umobileno": "mobilenumber"
                        },
                        {
                            "upagerno": "pagernumber"
                        },
                        {
                            "ufname": "firstname"
                        },
                        {
                            "uminitial": "initialname"
                        },
                        {
                            "ulname": "lastname"
                        },
                        {
                            "uemail": "email"
                        },
                        {
                            "upaddress": "address"
                        },
                        {
                            "upcity": "city"
                        },
                        {
                            "upPhone": "phonenumber"
                        },
                        {
                            "UserType": "usertype"
                        },
                        {
                            "dob": "dob"
                        },
                        {
                            "ssn": "ssn"
                        },
                        {
                            "upaddress2": "address2"
                        },
                        {
                            "initials": "initials"
                        },
                        {
                            "ptDob": "ptdob"
                        },
                        {
                            "upreviousname": "upreviousname"
                        },
                        {
                            "patient_id": "patientid"
                        }
                    ],
                    "primary_column_name": "patientid",
                    "primary_column_type": "patientid"
                },
                "patients": {
                    "required_columns": [
                        {
                            "employername": "employername"
                        },
                        {
                            "employeraddress": "address"
                        },
                        {
                            "employeraddress2": "address2"
                        },
                        {
                            "employercity": "employercity"
                        },
                        {
                            "employerPhone": "mobilenumber"
                        },
                        {
                            "insname": "insname"
                        },
                        {
                            "insgroupno": "insgroupno"
                        },
                        {
                            "inssubscriberno": "inssubscriberno"
                        },
                        {
                            "inscopay": "inscopay"
                        },
                        {
                            "insname2": "insname2"
                        },
                        {
                            "insgroupno2": "insgroupno2"
                        },
                        {
                            "inssubscriberno2": "inssubscriberno2"
                        },
                        {
                            "inscopay2": "inscopay2"
                        },
                        {
                            "straddress": "straddress"
                        },
                        {
                            "city": "city"
                        },
                        {
                            "insId": "insId"
                        },
                        {
                            "insId2": "insId2"
                        },
                        {
                            "strAddress2": "strAddress2"
                        },
                        {
                            "GrId": "GrId"
                        },
                        {
                            "preferred_name": "firstname"
                        },
                        {
                            "patient_id": "patientid"
                        }
                    ],
                    "primary_column_name": "patientid",
                    "primary_column_type": "patientid"
                }
            },
            "table_columns": [
                "inscopay2",
                "dob",
                "firstname",
                "insId2",
                "initialname",
                "password",
                "ssn",
                "patientid",
                "initials",
                "email",
                "employername",
                "address",
                "usertype",
                "inssubscriberno2",
                "straddress",
                "inscopay",
                "pagernumber",
                "upreviousname",
                "insgroupno",
                "city",
                "GrId",
                "strAddress2",
                "mobilenumber",
                "inssubscriberno",
                "insname",
                "lastname",
                "address2",
                "insgroupno2",
                "insId",
                "phonenumber",
                "insname2",
                "ptdob",
                "username",
                "employercity"
            ]
        },
        "master_insurance_table": {
            "source_tables": {
                "hcfa": {
                    "required_columns": [
                        {
                            "PName": "patientname"
                        },
                        {
                            "InsuredName": "insuredname"
                        },
                        {
                            "InsuredId": "insuredid"
                        },
                        {
                            "PAddressStreet": "patientaddressstreet"
                        },
                        {
                            "PAddressCity": "patientaddresscity"
                        },
                        {
                            "InsuredAddStreet": "insuredaddressstreet"
                        },
                        {
                            "InsuredAddCity": "insuredaddresscity"
                        },
                        {
                            "NameRef": "nameref"
                        },
                        {
                            "SSN": "ssn"
                        },
                        {
                            "EmpOrSchoolName": "employerorschoolname"
                        },
                        {
                            "InsurancePlan": "insuranceplan"
                        },
                        {
                            "OtherInsuredName": "otherinsuredname"
                        },
                        {
                            "OtherEmpName": "otheremployername"
                        },
                        {
                            "OtherInsuranceName": "otherinsurancename"
                        },
                        {
                            "PayorName1": "payorname1"
                        },
                        {
                            "PayorName2": "payorname2"
                        },
                        {
                            "PayorName3": "payorname3"
                        },
                        {
                            "PayorAddress11": "payoraddress11"
                        },
                        {
                            "PayorAddress12": "payoraddress12"
                        },
                        {
                            "PayorAddress13": "payoraddress13"
                        },
                        {
                            "PayorAddress21": "payoraddress21"
                        },
                        {
                            "PayorAddress22": "payoraddress22"
                        },
                        {
                            "PayorAddress23": "payoraddress23"
                        },
                        {
                            "PayorCity1": "payorcity1"
                        },
                        {
                            "PayorZip1": "payorzip1"
                        },
                        {
                            "PayorCity2": "payorcity2"
                        },
                        {
                            "PayorZip2": "payorzip2"
                        },
                        {
                            "PayorCity3": "payorcity3"
                        },
                        {
                            "PayorZip3": "payorzip3"
                        },
                        {
                            "patient_id": "patientid"
                        }
                    ],
                    "primary_column_name": "patientid",
                    "primary_column_type": "patientid"
                }
            },
            "table_columns": [
                "insuredaddresscity",
                "payorname3",
                "payorzip1",
                "payorcity3",
                "otherinsuredname",
                "payoraddress13",
                "nameref",
                "payoraddress21",
                "insuranceplan",
                "payorzip2",
                "payoraddress11",
                "otheremployername",
                "payorcity1",
                "payoraddress12",
                "payorname1",
                "patientaddresscity",
                "payoraddress23",
                "employerorschoolname",
                "insuredaddressstreet",
                "payorzip3",
                "payorcity2",
                "patientid",
                "otherinsurancename",
                "insuredname",
                "payorname2",
                "insuredid",
                "payoraddress22",
                "patientname",
                "patientaddressstreet",
                "ssn"
            ]
        }
    }
}
c.save()

# %%
c.master_db_config
# Out:
# {'pii_schema_name': 'master_prod',
#  'pii_tables': {'pii_data_table': {'source_tables': {'users': {'required_columns': [{'uname': 'username'},
#       {'upwd': 'password'},
#       {'umobileno': 'mobilenumber'},
#       {'upagerno': 'pagernumber'},
#       {'ufname': 'firstname'},
#       {'uminitial': 'initialname'},
#       {'ulname': 'lastname'},
#       {'uemail': 'email'},
#       {'upaddress': 'address'},
#       {'upcity': 'city'},
#       {'upPhone': 'phonenumber'},
#       {'UserType': 'usertype'},
#       {'dob': 'dob'},
#       {'ssn': 'ssn'},
#       {'upaddress2': 'address2'},
#       {'initials': 'initials'},
#       {'ptDob': 'ptdob'},
#       {'upreviousname': 'upreviousname'},
#       {'patient_id': 'patientid'}],
#      'primary_column_name': 'patientid',
#      'primary_column_type': 'patientid'},
#     'patients': {'required_columns': [{'employername': 'employername'},
#       {'employeraddress': 'address'},
#       {'employeraddress2': 'address2'},
#       {'employercity': 'employercity'},
#       {'employerPhone': 'mobilenumber'},
#       {'insname': 'insname'},
#       {'insgroupno': 'insgroupno'},
#       {'inssubscriberno': 'inssubscriberno'},
#       {'inscopay': 'inscopay'},
#       {'insname2': 'insname2'},
#       {'insgroupno2': 'insgroupno2'},
#       {'inssubscriberno2': 'inssubscriberno2'},
#       {'inscopay2': 'inscopay2'},
#       {'straddress': 'straddress'},
#       {'city': 'city'},
#       {'insId': 'insId'},
#       {'insId2': 'insId2'},
#       {'strAddress2': 'strAddress2'},
#       {'GrId': 'GrId'},
#       {'preferred_name': 'firstname'},
#       {'patient_id': 'patientid'}],
#      'primary_column_name': 'patientid',
#      'primary_column_type': 'patientid'}},
#    'table_columns': ['inscopay2',
#     'dob',
#     'firstname',
#     'insId2',
#     'initialname',
#     'password',
#     'ssn',
#     'patientid',
#     'initials',
#     'email',
#     'employername',
#     'address',
#     'usertype',
#     'inssubscriberno2',
#     'straddress',
#     'inscopay',
#     'pagernumber',
#     'upreviousname',
#     'insgroupno',
#     'city',
#     'GrId',
#     'strAddress2',
#     'mobilenumber',
#     'inssubscriberno',
#     'insname',
#     'lastname',
#     'address2',
#     'insgroupno2',
#     'insId',
#     'phonenumber',
#     'insname2',
#     'ptdob',
#     'username',
#     'employercity']},
#   'master_insurance_table': {'source_tables': {'hcfa': {'required_columns': [{'PName': 'patientname'},
#       {'InsuredName': 'insuredname'},
#       {'InsuredId': 'insuredid'},
#       {'PAddressStreet': 'patientaddressstreet'},
#       {'PAddressCity': 'patientaddresscity'},
#       {'InsuredAddStreet': 'insuredaddressstreet'},
#       {'InsuredAddCity': 'insuredaddresscity'},
#       {'NameRef': 'nameref'},
#       {'SSN': 'ssn'},
#       {'EmpOrSchoolName': 'employerorschoolname'},
#       {'InsurancePlan': 'insuranceplan'},
#       {'OtherInsuredName': 'otherinsuredname'},
#       {'OtherEmpName': 'otheremployername'},
#       {'OtherInsuranceName': 'otherinsurancename'},
#       {'PayorName1': 'payorname1'},
#       {'PayorName2': 'payorname2'},
#       {'PayorName3': 'payorname3'},
#       {'PayorAddress11': 'payoraddress11'},
#       {'PayorAddress12': 'payoraddress12'},
#       {'PayorAddress13': 'payoraddress13'},
#       {'PayorAddress21': 'payoraddress21'},
#       {'PayorAddress22': 'payoraddress22'},
#       {'PayorAddress23': 'payoraddress23'},
#       {'PayorCity1': 'payorcity1'},
#       {'PayorZip1': 'payorzip1'},
#       {'PayorCity2': 'payorcity2'},
#       {'PayorZip2': 'payorzip2'},
#       {'PayorCity3': 'payorcity3'},
#       {'PayorZip3': 'payorzip3'},
#       {'patient_id': 'patientid'}],
#      'primary_column_name': 'patientid',
#      'primary_column_type': 'patientid'}},
#    'table_columns': ['insuredaddresscity',
#     'payorname3',
#     'payorzip1',
#     'payorcity3',
#     'otherinsuredname',
#     'payoraddress13',
#     'nameref',
#     'payoraddress21',
#     'insuranceplan',
#     'payorzip2',
#     'payoraddress11',
#     'otheremployername',
#     'payorcity1',
#     'payoraddress12',
#     'payorname1',
#     'patientaddresscity',
#     'payoraddress23',
#     'employerorschoolname',
#     'insuredaddressstreet',
#     'payorzip3',
#     'payorcity2',
#     'patientid',
#     'otherinsurancename',
#     'insuredname',
#     'payorname2',
#     'insuredid',
#     'payoraddress22',
#     'patientname',
#     'patientaddressstreet',
#     'ssn']}}}

# %%
Table.objects.filter(table_name="progressnotes")
# Out:
# (1, {'nd_api.Table': 1})

# %%
Table.objects.filter(table_name="users").last().metadata.primary_key
# Out:
# {'primary_key': ['uid']}
