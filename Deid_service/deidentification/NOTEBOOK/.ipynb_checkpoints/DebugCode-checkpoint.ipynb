# %%
import os
import django
import sys
# Set up Django environment
sys.path.append('K:\\deidentification\\deIdentification')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from nd_api.views.de_identification_task import create_deidentification_task
from nd_api.models import DbDetailsModel, TableDetailsModel
from worker.models import Task, Chain
from django.contrib.auth.models import User
from keycloakauth.rolemodel import RoleModel, get_default_permissions
from nd_scripts.create_account import create_account
from nd_api.views.db_views import create_stats_generation_tasks
from core.process.main import start_de_identification_for_table
from nd_api.views.de_identification_task import create_deidentification_task

def clean_db():
    RoleModel.objects.all().delete()
    User.objects.all().delete()
    DbDetailsModel.objects.all().delete()
    Chain.objects.all().delete()

# %%
# mysql+pymysql://root:123456789@localhost:3306/nddenttest

# %%
# mysql+pymysql://root:123456789@localhost:3306/full_automation

# %%
# MAPPING_TABLE_SCHEMA = {
#     "patient_table_name": "patient",
#     "encounter_table_name": "encounter",
#     "patient_id_column": "patient_id",
#     "encounter_id_column": "encounter_id",
#     "offset_column": "offset",
#     "nd_patient_id_column": "nd_patient_id",
#     "nd_encounter_id_column": "nd_encounter_id"
# }

MAPPING_DB_CONNECTION_STRING = "mysql+pymysql://root:123456789@localhost:3306/nddenttest_mapping"

# %%
db_model = DbDetailsModel.objects.get(
    db_name="tng_deidentification",
    # db_type="mysql",
    # db_config={'config': db_config}
)

# %%
db_model.source_db_config = {
    "connection_str": "mssql+pyodbc://mssqlserver:ndTNG2024%40@localhost/FMQazi?driver=ODBC+Driver+17+for+SQL+Server"
}
db_model.save()

# %%
db_model.destination_db_config = {
    "connection_str": "mysql+pymysql://ndadmin:ndTNG%402024%23@10.20.20.5:3306/deidentified"
}
db_model.save()

# %%
db_model.run_config["mapping_db_config"] = {
    "connection_string": "mysql+pymysql://ndadmin:ndTNG%402024%23@10.20.20.5:3306/mapping",
    "inhouse_mapping_table": False,
}
db_model.save()

# %%
# DbDetailsModel.objects.all().delete()

# %%
db_model.run_config
# Out:
# {'mapping_db_config': {'connection_string': 'mysql+pymysql://ndadmin:ndTNG%402024%23@10.20.20.5:3306/mapping',
#   'inhouse_mapping_table': False}}

# %%
for tablem in TableDetailsModel.objects.all():
    print(tablem.table_name, tablem.id, tablem.rows_count)
# Out:
# facilities 73 100000
# users 74 10000
# enc_table 72 29888

# %%
td = TableDetailsModel.objects.get(id=74)
td.table_details_for_ui
# Out:
# {'batch_size': 1,
#  'ignore_config': {'operator': 'and', 'ignore_rows': []},
#  'columns_details': [{'is_phi': True,
#    'mask_value': None,
#    'column_name': 'uid',
#    'ignore_column': {},
#    'add_to_phi_table': False,
#    'de_identification_rule': 'PATIENT_ID',
#    'column_name_for_phi_table': None},
#   {'is_phi': True,
#    'mask_value': '<<PATIENT_NAME>>',
#    'column_name': 'patient_name',
#    'ignore_column': {},
#    'add_to_phi_table': False,
#    'de_identification_rule': 'MASK',
#    'column_name_for_phi_table': None},
#   {'is_phi': True,
#    'mask_value': '<<PATIENT_NAME>>',
#    'column_name': 'uname',
#    'ignore_column': {},
#    'add_to_phi_table': False,
#    'de_identification_rule': 'MASK',
#    'column_name_for_phi_table': None},
#   {'is_phi': True,
#    'mask_value': '<<UPWD>>',
#    'column_name': 'upwd',
#    'ignore_column': {},
#    'add_to_phi_table': False,
#    'de_identification_rule': 'MASK',
#    'column_name_for_phi_table': None},
# ...

# %%
from worker.models import Task, Chain

# %%
t = Task.objects.filter(type="core.process.main.start_de_identification_for_table").last()
t.failure_count = 0
t.save()
t
# Out:
# Task(id=123, type=core.process.main.start_de_identification_for_table, arguments=({'hooks': {'failure'...), status=0, num_dependencies=0, num_dependencies_pending=0, failure_count=0)

# %%
Task.objects.filter(status=2)
# Out:
# <QuerySet [Task(id=118, type=nd_api.views.stats_generation.RunStatsGenerationTask, arguments=({'db_details_id': 10...), status=2, num_dependencies=0, num_dependencies_pending=0, failure_count=0)]>

# %%
td = TableDetailsModel.objects.get(table_name="enc")
td.table_progress_status.table_status = 3
td.table_progress_status.save()
td.table_progress_status.table_status
# Out:
# 3

# %%
table = TableDetailsModel.objects.get(id=3)
table.is_phi_marking_locked = True
table.save()

# %%
# role.permissions = {
#             "AddDataBase": {
#                 "has_permission": True
#             },
#             "UploadPHIConfigCSV": {
#                 "has_permission": True
#             },
#             "UpdatePHIConfig": {
#                 "has_permission": True
#             },
#             "PHIMarkingCompletedTick": {
#                 "has_permission": True
#             },
#             "PHIMarkingVerifiedTick": {
#                 "has_permission": True
#             },
#             "TableQCTick": {
#                 "has_permission": True
#             },
#             "UnLockPHIMarkingDB": {
#                 "has_permission": True
#             },
#             "LockPHIMarkingDB": {
#                 "has_permission": True
#             },
#             "StartDeIdentificationButton": {
#                 "has_permission": True
#             },
#         }
# role.save()

# %%
tdm = TableDetailsModel.objects.last()
