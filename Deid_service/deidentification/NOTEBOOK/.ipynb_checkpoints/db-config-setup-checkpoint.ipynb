# %%
import os
import django
import sys
# Set up Django environment
sys.path.append('F:\Soorykant\deidentification\deIdentification')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from nd_api.views.de_identification_task import create_deidentification_task
from nd_api.models import DbDetailsModel, TableDetailsModel
from worker.models import Task, Chain
from django.contrib.auth.models import User
from keycloakauth.rolemodel import RoleModel, get_default_permissions
from nd_scripts.create_account import create_account
from nd_api.views.db_views import create_stats_generation_tasks
from core.process.main import start_de_identification_for_table
from nd_api.views.de_identification_task import create_deidentification_task

def clean_db():
    RoleModel.objects.all().delete()
    User.objects.all().delete()
    DbDetailsModel.objects.all().delete()
    Chain.objects.all().delete()

# %%
db = DbDetailsModel.objects.get(db_name="prod_data")

# %%
db.source_db_config = {
    "connection_str": 'mysql+pymysql://nd-read:ndREAD%402025@172.36.1.4:3306/mobiledoc'
}
db.destination_db_config = {
    "connection_str": 'mysql+pymysql://ndadmin:ndADMIN%402025@172.36.1.4:3306/deidentified'
}
db.run_config["mapping_db_config"] = {
    "connection_str": "mysql+pymysql://nd-read:ndREAD%402025@172.36.1.4:3306/mapping",
    "inhouse_mapping_table": False,
}
db.run_config["universal_tables_config"] = [
    {
        "connection_str": 'mysql+pymysql://nd-read:ndREAD%402025@172.36.1.4:3306/master',
        "table_name": "facility_pii_data",
        "column_mapping": {
            "edi_facilities_Name": "((FacilityName))",
            "edi_facilities_AddressLine1": "((FacilityDetails))",
            "edi_facilities_AddressLine2": "((FacilityDetails))",
            "edi_facilities_City": "((FacilityDetails))",
            "edi_facilities_Tel": "((FacilityDetails))",
            "edi_facilities_Fax": "((FacilityDetails))",
            "edi_facilities_EMail": "((FacilityDetails))",
            "edi_facilities_BillingAddressLine1": "((FacilityDetails))",
            "edi_facilities_BillingAddressLine2": "((FacilityDetails))",
            "edi_facilities_BillingCity": "((FacilityDetails))",
            "edi_facilities_BillingTel": "((FacilityDetails))",
            "edi_facilities_BillingFax": "((FacilityDetails))",
            "edi_facilities_BillingEMail": "((FacilityDetails))",
            "edi_facilities_PayableTo": "((FacilityName))",
            "edi_facilities_NPI": "((FacilityDetails))",
            "edi_facilities_MessCallerId": "((FacilityDetails))",
            "edi_facilities_MessOperNum": "((FacilityDetails))",
            "edi_facilities_facilitynickname": "((FacilityDetails))",
            "edi_facilities_portal_name": "((FacilityDetails))",
        }

    },
    {
        "connection_str": 'mysql+pymysql://nd-read:ndREAD%402025@172.36.1.4:3306/master',
        "table_name": "insurance_pii_data",
        "column_mapping": {
            "hcfa_PName": "PatientName",
            "hcfa_InsuredName": "PatientName",
            "hcfa_InsuredId": "InsuranceID",
            "hcfa_PAddressStreet": "PatientAddress",
            "hcfa_PAddressCity": "PatientAddress",
            "hcfa_InsuredAddStreet": "PatientAddress",
            "hcfa_InsuredAddCity": "PatientAddress",
            "hcfa_IPhoneArea": "PatientPhone",
            "hcfa_IPhoneDigits": "PatientPhone",
            "hcfa_InsuredPolicyGroup": "InsuranceDetails",
            "hcfa_NameRef": "InsuranceDetails",
            "hcfa_SSN": "PatientSNN",
            "hcfa_PPhoneDigits": "PatientPhone",
            "hcfa_MedGrpID": "InsuranceDetails",
            "hcfa_Facility": "FacilityName",
            "hcfa_FacAddress": "FacilityDetails",
            "hcfa_EmpOrSchoolName": "InsuranceDetails",
            "hcfa_InsurancePlan": "InsuranceDetails",
            "hcfa_OtherInsuredName": "InsuranceDetails",
            "hcfa_OthergroupNo": "InsuranceDetails",
            "hcfa_OtherEmpName": "EmployerDetails",
            "hcfa_OtherInsuranceName": "InsuranceDetails",
            "hcfa_ProviderOrgName": "FacilityDetails",
            "hcfa_PayorName1": "PatientName",
            "hcfa_PayorName2": "PatientName",                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
            "hcfa_PayorName3": "PatientName",
            "hcfa_PayorAddress11": "PatientAddress",
            "hcfa_PayorAddress12": "PatientAddress",
            "hcfa_PayorAddress13": "PatientAddress",
            "hcfa_PayorAddress21": "PatientAddress",
            "hcfa_PayorAddress22": "PatientAddress",
            "hcfa_PayorAddress23": "PatientAddress",
            "hcfa_PayorCity1": "PatientAddress",
            "hcfa_PayorCity2": "PatientAddress",
            "hcfa_PayorCity3": "PatientAddress",
            "hcfa_FacCity": "FacilityDetails",
            "hcfa_FacNumber": "FacilityDetails",
            "hcfa_GroupPlan": "InsuranceDetails",
            "hcfa_OtherPlan": "InsuranceDetails"
        }
    }
]
db.run_config["pii_db_config"] = {
    "connection_str": 'mysql+pymysql://nd-read:ndREAD%402025@172.36.1.4:3306/master',
}
db.run_config['pii_config'] = master_pii_dict = {
    "mask": {
        "users_uname": {
            "masking_value": "((PatientDetail))",
            "regex": None,
            "processing_func": None,
        },
        "users_upwd": {
            "masking_value": "((PatientDetail))",
            "regex": None,
            "processing_func": None,
        },
        "users_umobileno": {
            "masking_value": "((PatientPhone))",
            "regex": None,
            "processing_func": None,
        },
        "users_upagerno": {
            "masking_value": "((PatientPhone))",
            "regex": None,
            "processing_func": None,
        },
        "users_ufname": {
            "masking_value": "((PatientName))",
            "regex": None,
            "processing_func": None,
        },
        "users_uminitial": {
            "masking_value": "((PatientName))",
            "regex": None,
            "processing_func": None,
        },
        "users_ulname": {
            "masking_value": "((PatientName))",
            "regex": None,
            "processing_func": None,
        },
        "users_uemail": {
            "masking_value": "((PatientEmail))",
            "regex": None,
            "processing_func": None,
        },
        "users_upaddress": {
            "masking_value": "((PatientAddress))",
            "regex": None,
            "processing_func": None,
        },
        "users_upcity": {
            "masking_value": "((PatientAddress))",
            "regex": None,
            "processing_func": None,
        },
        "users_upPhone": {
            "masking_value": "((PatientPhone))",
            "regex": None,
            "processing_func": None,
        },
        "users_ssn": {
            "masking_value": "((PatientSSN))",
            "regex": None,
            "processing_func": None,
        },
        "users_upaddress2": {
            "masking_value": "((PatientAddress))",
            "regex": None,
            "processing_func": None,
        },
        "users_initials": {
            "masking_value": "((PatientName))",
            "regex": None,
            "processing_func": None,
        },
        "users_upreviousname": {
            "masking_value": "((PatientName))",
            "regex": None,
            "processing_func": None,
        },
        "patients_employername": {
            "masking_value": "((EmployerName))",
            "regex": None,
            "processing_func": None,
        },
        "patients_employeraddress": {
            "masking_value": "((EmployerDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_employeraddress2": {
            "masking_value": "((EmployerDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_employercity": {
            "masking_value": "((EmployerDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_employerPhone": {
            "masking_value": "((EmployerDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_insname": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_insgroupno": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_inssubscriberno": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_inscopay": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_insname2": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_insgroupno2": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_inssubscriberno2": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_inscopay2": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_straddress": {
            "masking_value": "((PatientAddress))",
            "regex": None,
            "processing_func": None,
        },
        "patients_city": {
            "masking_value": "((PatientAddress))",
            "regex": None,
            "processing_func": None,
        },
        
        "patients_insId": {
            "masking_value": "((EmployerPhone))",
            "regex": None,
            "processing_func": None,
        },
        "patients_insId2": {
            "masking_value": "((InsuranceDetails))",
            "regex": None,
            "processing_func": None,
        },
        "patients_strAddress2": {
            "masking_value": "((PatientAddress))",
            "regex": None,
            "processing_func": None,
        },
        "patients_GrId": {
            "masking_value": "((PatientDetail))",
            "regex": None,
            "processing_func": None,
        },
        "patients_preferred_name": {
            "masking_value": "((PatientName))",
            "regex": None,
            "processing_func": None,
        },

    },
    "combine": {
        "patientfullname": {
            "combine": ["users_uname", "users_ufname", "users_uminitial", "users_ulname", "users_initials", "users_upreviousname", "patients_preferred_name"],
            "masking_value": "((PatientName))",
            "regex": None,
            "processing_func": None,
        },
    },
    "dob": {
        "users_dob": {"masking_value": "((PatientDOB))", "regex": None, "processing_func": None},
        "users_ptDob": {"masking_value": "((PatientDOB))", "regex": None, "processing_func": None},
    },
    "regex": {
        "users_uemail": {
            "masking_value": "((PatientEmail))",
            "regex": [r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"],
            "processing_func": None,
        },
        "users_ssn": {
            "masking_value": "((PatientSSN))",
            "regex": [r"\b\d{3}[- ]\d{2}[- ]\d{4}\b"],
            "processing_func": None,
        },
        "users_umobileno": {
            "masking_value": "((PHONENUMBER))",
            "regex": [
                r"\(\d{3}\)\s*\d{3}-\d{4}",  # (XXX) XXX-XXXX
                r"\b\d{3}-\d{3}-\d{4}\b",  # XXX-XXX-XXXX
                r"\+\d{1,3}\s\d{1,4}[- ]\d{3}[- ]\d{4}\b",  # International format
                r"\b\d{3} \d{3} \d{4}\b",  # XXX XXX XXXX (with spaces)
            ],
            "processing_func": None,
        },
        "users_upPhone": {
            "masking_value": "((PHONENUMBER))",
            "regex": [
                r"\(\d{3}\)\s*\d{3}-\d{4}",  # (XXX) XXX-XXXX
                r"\b\d{3}-\d{3}-\d{4}\b",  # XXX-XXX-XXXX
                r"\+\d{1,3}\s\d{1,4}[- ]\d{3}[- ]\d{4}\b",  # International format
                r"\b\d{3} \d{3} \d{4}\b",  # XXX XXX XXXX (with spaces)
            ],
            "processing_func": None,
        },
        "patients_employerPhone": {
            "masking_value": "((EmployerDetails))",
            "regex": [
                r"\(\d{3}\)\s*\d{3}-\d{4}",  # (XXX) XXX-XXXX
                r"\b\d{3}-\d{3}-\d{4}\b",  # XXX-XXX-XXXX
                r"\+\d{1,3}\s\d{1,4}[- ]\d{3}[- ]\d{4}\b",  # International format
                r"\b\d{3} \d{3} \d{4}\b",  # XXX XXX XXXX (with spaces)
            ],
            "processing_func": None,
        },
    }
}


db.save()
