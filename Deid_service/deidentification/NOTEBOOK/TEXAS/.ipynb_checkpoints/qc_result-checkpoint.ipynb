# %%
import os
import django
import sys
import json
# Set up Django environment
sys.path.append(
    "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/"
)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()
import requests
from nd_api.models import Clients, Table, TableMetadata, ClientDataDump
from nd_api.views.utils import register_table_and_generate_analytics
import pandas as pd
from nd_api.views.dump_view import add_nd_auto_increment_id_column
import requests
from nd_api.models import Clients, Table, TableMetadata, ClientDataDump, Status
from nd_api.views.utils import register_table_and_generate_analytics

from worker.models import Task, Chain

# %%
import csv

# %%
import csv

def is_notes_table(table_obj: Table):
    is_notes = False
    for col_conf in table_obj.table_details_for_ui['columns_details']:
        if col_conf['de_identification_rule'] in ["NOTES", "GENERIC_NOTES"]:
            is_notes = True
            break
    return is_notes

def patient_ientifier_count(table_obj: Table):
    count = 0
    for col_conf in table_obj.table_details_for_ui['columns_details']:
        if not col_conf['is_phi']:
            continue
        if col_conf['de_identification_rule'].startswith("PATIENT_"):
            count += 1
        elif col_conf['de_identification_rule'] == "ENCOUNTER_ID":
            count += 1
        elif col_conf['de_identification_rule'] == "APPOINTMENT_ID":
            count += 1
    return count

def no_of_columns(table_obj):
    return len(table_obj.table_details_for_ui['columns_details'])

def no_of_phi_columns(table_obj):
    return len([col_conf for col_conf in table_obj.table_details_for_ui['columns_details'] if col_conf['is_phi']])

def get_qc_results(output_path, dump_id,tables_names=[]):
    if not tables_names:
        # tables_names = Table.objects.filter(dump=dump_id, deid__deid_status=Status.COMPLETED).filter(qc__qc_status__in=[2, -1]).values_list("table_name", flat=True)
        tables_names = Table.objects.filter(dump=dump_id, deid__deid_status=Status.COMPLETED).values_list("table_name", flat=True)
    output = []
    for table_name in tables_names:
        table = Table.objects.get(table_name=table_name, dump_id=dump_id)
        qc_results = table.qc.qc_result
        patient_identifier_count = patient_ientifier_count(table)
        total_columns = no_of_columns(table)
        phi_columns = no_of_phi_columns(table)

        dest_handler = table.dump.get_destination_db_connection()
        if "dest_rows_count" in qc_results:
            dest_rows_count = qc_results['dest_rows_count']
        else:
            try:
                dest_rows_count = dest_handler.get_rows_count(table_name)
            except:
                dest_rows_count = "FOUND_ISSUE_IN_GETTING_COUNT"
        
        output.append({
            "table_name": table_name, 
            "qc_results": qc_results, 
            "is_qc_passed": table.qc.qc_status == Status.COMPLETED,
            "unstructured": is_notes_table(table),
            "patient_identifier_count": patient_identifier_count,
            "total_columns": total_columns,
            "phi_columns": phi_columns,
            "src_rows_count": table.rows_count,
            "dest_rows_count": dest_rows_count,
        })
    
    with open(output_path, "w") as f:
        writer = csv.writer(f)
        writer.writerow(["table_name", "qc_results", "is_qc_passed", "unstructured", "patient_identifier_count", "total_columns", "phi_columns", "original_rows_count", "deidentified_rows_count"])
        for row in output:
            writer.writerow([row["table_name"], row["qc_results"], row["is_qc_passed"], row["unstructured"], row["patient_identifier_count"], row["total_columns"], row["phi_columns"], row["src_rows_count"], row["dest_rows_count"]])

# %%
outputpath = "/Users/ndaitexasneurology/Documents/DEPORTAL/faltu_work/qc_results_14oct.csv"
get_qc_results(outputpath, 1)
# Out:
# 2025-10-14 19:04:32,784 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,791 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,804 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,817 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,829 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,840 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,851 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,866 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,879 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,908 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,919 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,938 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,948 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,961 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,974 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:32,993 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,002 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,010 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,032 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,051 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,059 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,076 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,092 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,101 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,107 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,113 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,119 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,130 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,140 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,148 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,158 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,207 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,230 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,237 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,244 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,253 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,274 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,343 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,349 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,354 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,367 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,406 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,466 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,653 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-14 19:04:33,707 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:33,940 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:33,971 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:33,978 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:33,988 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:34,004 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:34,017 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:34,027 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 493, in rollback
#     self._read_ok_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 453, in _read_ok_packet
#     pkt = self._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 753, in _read_packet
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 493, in rollback
#     self._read_ok_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 453, in _read_ok_packet
#     pkt = self._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 753, in _read_packet
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 493, in rollback
#     self._read_ok_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 453, in _read_ok_packet
#     pkt = self._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 753, in _read_packet
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 493, in rollback
#     self._read_ok_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 453, in _read_ok_packet
#     pkt = self._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 753, in _read_packet
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 493, in rollback
#     self._read_ok_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 453, in _read_ok_packet
#     pkt = self._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 753, in _read_packet
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 493, in rollback
#     self._read_ok_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 453, in _read_ok_packet
#     pkt = self._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 753, in _read_packet
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2013, 'Lost connection to MySQL server during query')
# 2025-10-15 03:04:38,359 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,366 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,383 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,450 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,468 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,485 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,499 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,505 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,510 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,516 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,523 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,529 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:38,537 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:42,271 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:42,286 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:42,296 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:42,306 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:42,325 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:42,337 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# 2025-10-15 03:04:42,346 - deIdentification.nd_logger - INFO - Database 'deidentify_client_1_dump_1' created successfully.
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/lj/kz1dk6cn3jlbrd5b592sbsn00000gn/T/ipykernel_96919/444114158.py", line 2, in <module>
#     get_qc_results(outputpath, 1)
#   File "/var/folders/lj/kz1dk6cn3jlbrd5b592sbsn00000gn/T/ipykernel_96919/3834203625.py", line 42, in get_qc_results
#     dest_handler = table.dump.get_destination_db_connection()
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 97, in get_destination_db_connection
#     dest_conn_str = self.get_destination_db_connection_str()
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 88, in get_destination_db_connection_str
#     dest_url = self._get_db_url(dest_db)
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 83, in _get_db_url
#     admin_dbhandler.create_database_if_not_exists(schema_name)
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/core/dbPkg/dbhandler.py", line 374, in create_database_if_not_exists
#     self.session.execute(create_db_query)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2362, in execute
#     return self._execute_internal(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2256, in _execute_internal
#     result = conn.execute(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1418, in execute
#     return meth(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/sql/elements.py", line 515, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1640, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1846, in _execute_context
#     return self._exec_single_context(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1986, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2358, in _handle_dbapi_exception
#     raise exc_info[1].with_traceback(exc_info[2])
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1967, in _exec_single_context
#     self.dialect.do_execute(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 941, in do_execute
#     cursor.execute(statement, parameters)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py", line 153, in execute
#     result = self._query(query)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py", line 322, in _query
#     conn.query(q)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 563, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 825, in _read_query_result
#     result.read()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 1199, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 744, in _read_packet
#     packet_header = self._read_bytes(4)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 782, in _read_bytes
#     data = self._rfile.read(num_bytes)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/socket.py", line 716, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 806, in _write_bytes
#     self._sock.sendall(data)
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 492, in rollback
#     self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 864, in _execute_command
#     self._write_bytes(packet)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 809, in _write_bytes
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2006, "MySQL server has gone away (BrokenPipeError(32, 'Broken pipe'))")
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/lj/kz1dk6cn3jlbrd5b592sbsn00000gn/T/ipykernel_96919/444114158.py", line 2, in <module>
#     get_qc_results(outputpath, 1)
#   File "/var/folders/lj/kz1dk6cn3jlbrd5b592sbsn00000gn/T/ipykernel_96919/3834203625.py", line 42, in get_qc_results
#     dest_handler = table.dump.get_destination_db_connection()
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 97, in get_destination_db_connection
#     dest_conn_str = self.get_destination_db_connection_str()
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 88, in get_destination_db_connection_str
#     dest_url = self._get_db_url(dest_db)
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 83, in _get_db_url
#     admin_dbhandler.create_database_if_not_exists(schema_name)
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/core/dbPkg/dbhandler.py", line 374, in create_database_if_not_exists
#     self.session.execute(create_db_query)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2362, in execute
#     return self._execute_internal(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2256, in _execute_internal
#     result = conn.execute(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1418, in execute
#     return meth(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/sql/elements.py", line 515, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1640, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1846, in _execute_context
#     return self._exec_single_context(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1986, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2358, in _handle_dbapi_exception
#     raise exc_info[1].with_traceback(exc_info[2])
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1967, in _exec_single_context
#     self.dialect.do_execute(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 941, in do_execute
#     cursor.execute(statement, parameters)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py", line 153, in execute
#     result = self._query(query)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py", line 322, in _query
#     conn.query(q)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 563, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 825, in _read_query_result
#     result.read()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 1199, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 744, in _read_packet
#     packet_header = self._read_bytes(4)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 782, in _read_bytes
#     data = self._rfile.read(num_bytes)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/socket.py", line 716, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 806, in _write_bytes
#     self._sock.sendall(data)
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 492, in rollback
#     self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 864, in _execute_command
#     self._write_bytes(packet)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 809, in _write_bytes
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2006, "MySQL server has gone away (BrokenPipeError(32, 'Broken pipe'))")
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/lj/kz1dk6cn3jlbrd5b592sbsn00000gn/T/ipykernel_96919/444114158.py", line 2, in <module>
#     get_qc_results(outputpath, 1)
#   File "/var/folders/lj/kz1dk6cn3jlbrd5b592sbsn00000gn/T/ipykernel_96919/3834203625.py", line 42, in get_qc_results
#     dest_handler = table.dump.get_destination_db_connection()
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 97, in get_destination_db_connection
#     dest_conn_str = self.get_destination_db_connection_str()
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 88, in get_destination_db_connection_str
#     dest_url = self._get_db_url(dest_db)
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py", line 83, in _get_db_url
#     admin_dbhandler.create_database_if_not_exists(schema_name)
#   File "/Users/ndaitexasneurology/Documents/DEPORTAL/deidentification/deIdentification/core/dbPkg/dbhandler.py", line 374, in create_database_if_not_exists
#     self.session.execute(create_db_query)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2362, in execute
#     return self._execute_internal(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2256, in _execute_internal
#     result = conn.execute(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1418, in execute
#     return meth(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/sql/elements.py", line 515, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1640, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1846, in _execute_context
#     return self._exec_single_context(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1986, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2358, in _handle_dbapi_exception
#     raise exc_info[1].with_traceback(exc_info[2])
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1967, in _exec_single_context
#     self.dialect.do_execute(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 941, in do_execute
#     cursor.execute(statement, parameters)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py", line 153, in execute
#     result = self._query(query)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py", line 322, in _query
#     conn.query(q)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 563, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 825, in _read_query_result
#     result.read()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 1199, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 744, in _read_packet
#     packet_header = self._read_bytes(4)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 782, in _read_bytes
#     data = self._rfile.read(num_bytes)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/socket.py", line 716, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 806, in _write_bytes
#     self._sock.sendall(data)
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 699, in do_rollback
#     dbapi_connection.rollback()
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 492, in rollback
#     self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 864, in _execute_command
#     self._write_bytes(packet)
#   File "/Users/ndaitexasneurology/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py", line 809, in _write_bytes
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2006, "MySQL server has gone away (BrokenPipeError(32, 'Broken pipe'))")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 outputpath = "/Users/ndaitexasneurology/Documents/DEPORTAL/faltu_work/qc_results_14oct.csv"
# ----> 2 get_qc_results(outputpath, 1)
#
# Cell In[4], line 42, in get_qc_results(output_path, dump_id, tables_names)
#      39 total_columns = no_of_columns(table)
#      40 phi_columns = no_of_phi_columns(table)
# ---> 42 dest_handler = table.dump.get_destination_db_connection()
#      43 if "dest_rows_count" in qc_results:
#      44     dest_rows_count = qc_results['dest_rows_count']
#
# File ~/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py:97, in ClientDataDump.get_destination_db_connection(self)
#      96 def get_destination_db_connection(self) -> NDDBHandler:
# ---> 97     dest_conn_str = self.get_destination_db_connection_str()
#      98     return NDDBHandler(dest_conn_str)
#
# File ~/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py:88, in ClientDataDump.get_destination_db_connection_str(self)
#      86 def get_destination_db_connection_str(self):
#      87     dest_db = self.get_destination_dbname()
# ---> 88     dest_url = self._get_db_url(dest_db)
#      89     return dest_url
#
# File ~/Documents/DEPORTAL/deidentification/deIdentification/nd_api/models/datadump.py:83, in ClientDataDump._get_db_url(self, schema_name)
#      81 db_url = admin_url.set(database=schema_name)
#      82 admin_dbhandler = NDDBHandler(admin_conn_str)
# ---> 83 admin_dbhandler.create_database_if_not_exists(schema_name)
#      84 return db_url.render_as_string(hide_password=False)
#
# File ~/Documents/DEPORTAL/deidentification/deIdentification/core/dbPkg/dbhandler.py:374, in NDDBHandler.create_database_if_not_exists(self, database_name)
#     372     nd_logger.error(f"Unsupported database dialect: {db_type}")
#     373     return
# --> 374 self.session.execute(create_db_query)
#     375 self.session.commit()
#     376 nd_logger.info(f"Database '{database_name}' created successfully.")
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py:2362, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2301 def execute(
#    2302     self,
#    2303     statement: Executable,
#    (...)
#    2309     _add_event: Optional[Any] = None,
#    2310 ) -> Result[Any]:
#    2311     r"""Execute a SQL expression construct.
#    2312
#    2313     Returns a :class:`_engine.Result` object representing
#    (...)
#    2360
#    2361     """
# -> 2362     return self._execute_internal(
#    2363         statement,
#    2364         params,
#    2365         execution_options=execution_options,
#    2366         bind_arguments=bind_arguments,
#    2367         _parent_execute_state=_parent_execute_state,
#    2368         _add_event=_add_event,
#    2369     )
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/orm/session.py:2256, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2247     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2248         self,
#    2249         statement,
#    (...)
#    2253         conn,
#    2254     )
#    2255 else:
# -> 2256     result = conn.execute(
#    2257         statement, params or {}, execution_options=execution_options
#    2258     )
#    2260 if _scalar_result:
#    2261     return result.scalar()
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2358, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2356     else:
#    2357         assert exc_info[1] is not None
# -> 2358         raise exc_info[1].with_traceback(exc_info[2])
#    2359 finally:
#    2360     del self._reentrant_error
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py:744, in Connection._read_packet(self, packet_type)
#     742 buff = bytearray()
#     743 while True:
# --> 744     packet_header = self._read_bytes(4)
#     745     # if DEBUG: dump_packet(packet_header)
#     747     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~/miniconda3/envs/deid/lib/python3.9/site-packages/pymysql/connections.py:782, in Connection._read_bytes(self, num_bytes)
#     780 while True:
#     781     try:
# --> 782         data = self._rfile.read(num_bytes)
#     783         break
#     784     except OSError as e:
#
# File ~/miniconda3/envs/deid/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
Table.objects.filter(dump_id=1, deid__deid_status=Status.COMPLETED).filter(qc__qc_status__in=[2, -1]).count()
# Out:
# 0

# %%
Table.objects.filter(dump_id=1, deid__deid_status=Status.COMPLETED).filter(table_name="doctorsinfo").last().qc.qc_result['dest_rows_count']
# Out:
# 71

# %%
Table.objects.filter(dump_id=1, deid__deid_status=Status.COMPLETED).filter(table_name="doctorsinfo").last().qc.qc_result['src_rows_count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Table.objects.filter(dump_id=1, deid__deid_status=Status.COMPLETED).filter(table_name="doctorsinfo").last().qc.qc_result['src_rows_count']
#
# KeyError: 'src_rows_count'

# %%
Table.objects.filter(dump_id=1, deid__deid_status=Status.COMPLETED).filter(table_name="doctorsinfo").last().qc.qc_result['source_rows_count']
# Out:
# 71
