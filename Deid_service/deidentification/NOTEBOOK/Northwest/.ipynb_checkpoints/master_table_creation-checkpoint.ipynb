# %%
import os
import django
import sys

# Set up Django environment
sys.path.append(
    "/nd_deployment/deIdentification/"
)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from core.dbPkg.phi_table.create_table import PIITable


pii_table_config = {
    "pii_data_table": {
        "primary_column_name": "patient_id",
        "upsert_instead_of_append": True,
        "tables": {
            "users": {
                "primary_col": "uid",
                "other_required_columns": [
                    "uname",
                    "UserType",
                    "upwd",
                    "umobileno",
                    "upagerno",
                    "ufname",
                    "uminitial",
                    "ulname",
                    "uemail",
                    "upaddress",
                    "upcity",
                    "upPhone",
                    "dob",
                    "ssn",
                    "upaddress2",
                    "initials",
                    "ptDob",
                    "upreviousname",
                ],
            },
            "patients": {
                "primary_col": "pid",
                "other_required_columns": [
                    "employername",
                    "employeraddress",
                    "employeraddress2",
                    "employercity",
                    "employerPhone",
                    "insname",
                    "insgroupno",
                    "inssubscriberno",
                    "inscopay",
                    "insname2",
                    "insgroupno2",
                    "inssubscriberno2",
                    "inscopay2",
                    "straddress",
                    "city",
                    "insId",
                    "insId2",
                    "strAddress2",
                    "GrId",
                    "preferred_name",
                ],
            },
        },
    }
}



import urllib.parse

encoded_password = urllib.parse.quote_plus("ndADMIN@2025")
# Connection String with Encoded Password
#src_db_url = "mssql+pyodbc://sa:ndADMIN2025@host.docker.internal:1433/mobiledoc?driver=ODBC+Driver+17+for+SQL+Server"
src_db_url = 'mysql+pymysql://ndadmin:ndADMIN%402025@host.docker.internal:3306/mobiledoc'


dest_db_url = f"mysql+pymysql://ndadmin:{encoded_password}@host.docker.internal:3306/master"
dest_db_url = 'mysql+pymysql://ndadmin:ndADMIN%402025@host.docker.internal:3306/master'


# src_db_url = "mysql+pymysql://root:Texas%402025@localhost/mobiledoc"
# dest_db_url = "mysql+pymysql://root:Texas%402025@localhost/master"
pii = PIITable(src_db_url, dest_db_url, pii_table_config)
pii.generate_pii_tables()
# Out:
# 2025-04-10 18:07:30,391 - deIdentification.nd_logger - INFO - Existing tables in source DB: ['9ehearts_measures', 'abncodes', 'abnicdcptmap', 'abnoptions', 'abs_session_timeout_logs', 'accassigncpts', 'accassignrules', 'accepted_pages', 'accessdeniedlogs', 'account_actions', 'account_number_logs', 'accounthold_log', 'accounts_assignedto_history', 'accounts_assignedto_historydetail', 'acg_acg_lookup', 'acg_adg_lookup', 'acg_condition', 'acg_condition_staging', 'acg_config', 'acg_coordination_risk_lookup', 'acg_cost_range_lookup', 'acg_dash_ptlist_columns', 'acg_ed_detail', 'acg_ed_detail_staging', 'acg_ed_lookup', 'acg_edc_lookup', 'acg_filters', 'acg_filters_saved', 'acg_frailty_concept_lookup', 'acg_frailty_concepts', 'acg_frailty_concepts_staging', 'acg_inpatient_detail', 'acg_inpatient_detail_staging', 'acg_input_file_status', 'acg_input_lab', 'acg_input_lab_staging', 'acg_input_medical_claim', 'acg_input_medical_cpt', 'acg_input_medical_diag', 'acg_input_medical_staging', 'acg_input_patient', 'acg_input_patient_staging', 'acg_input_pharmacy', 'acg_input_pharmacy_staging', 'acg_job_status', 'acg_majority_source_of_care_provider', 'acg_majority_source_of_care_provider_staging', 'acg_medc_lookup', 'acg_mm_acg', 'acg_mm_acg_staging', 'acg_mm_adg_madg', 'acg_mm_adg_madg_staging', 'acg_mm_medc_edc', 'acg_mm_medc_edc_staging', 'acg_mm_mrxmg_rxmg', 'acg_mm_mrxmg_rxmg_staging', 'acg_mrxmg_lookup', 'acg_output_file_status', 'acg_patientdata', 'acg_patientdata_staging', 'acg_rub', 'acg_rub_lookup', 'acg_rub_staging', 'acg_rxmg_lookup', 'acg_temp_pid', 'acg_untreated_rx', 'acg_untreated_rx_staging', 'acoprograms', 'actiondetails', 'actionpdmsgs', 'actionresultlogs', 'actions', 'actiontypefavourites', 'activemq_interop_listener_details', 'activityattendance', 'activitycalendar', 'activitydetail', 'activitydetailinfo', 'activitynonparticipationreasons', 'addendum_logs', 'addimmunizationlog', 'addimunizationlog', 'additionaladdress', 'additionalmasks', 'additionalmasksconfig', 'additionalmasksrules', 'additionalnotes', 'additionalnotes_logs', 'address_validation_properties', 'address_validation_properties_history', 'addressmanager', 'addresstype', 'adjpostableeracodes', 'adjustmentposting', 'admin_tblcreationlog', 'adminccmrproblemreviewsetup', 'admindbsettings', 'adminlogs', 'adminlogs_policy', 'adminlogs_policy_detail', 'adminlogsdata', 'adminlogtrg', 'adminsites', 'adtinbounddocuments', 'advance_directives', 'advancedsupportsystemmenuitems', 'advancedsupportsystemotpdetails', 'advancepmtplanconfig_logs', 'advicerecommendations', 'advpaymentplanbalanceconfiguration', 'advpaymentplantermoptions', 'afp', 'aftercarestatuscodes', 'aftercarestatushistory', 'aftercaresubstatuscodes', 'agegroupname', 'agegroupnamedetail', 'agentservicevalidation', 'agentservicevalidationlogs', 'ages_seen', 'ahca', 'ai_acknowledgements', 'ai_bundleconfiguration', 'ai_doc_assistant_applied_log', 'ai_doc_assistant_screen_mapping', 'ai_lead', 'ai_leadlog', 'ai_product', 'ai_translatable_languages', 'ai_translation_details', 'aidocumentcategories', 'aigb_user_info', 'alert_clearinghouse_config', 'alert_status', 'alertdata', 'alertdata_status', 'alertdb_claimgroups', 'alertdb_claimgroupsstatusrel', 'alertoverride', 'alertoverridedetails', 'alertpriority', 'alerts_imported_into_progressnote', 'alertsfromihub', 'allergies', 'allergiesnotfoundlist', 'allergy_allergen_inventory_mapping', 'allergy_barcode_setting', 'allergy_bottle_no_config', 'allergy_bottleno_configuration', 'allergy_checkin_dtl', 'allergy_conf_cat_allergen_logs', 'allergy_configuration_logs', 'allergy_diluent_inventory_mapping', 'allergy_duetoday_logs', 'allergy_element_mapping', 'allergy_exbilling_logs', 'allergy_extract_billing', 'allergy_extract_billing_notes', 'allergy_extracts', 'allergy_extracts_icd', 'allergy_extracts_icdcodes', 'allergy_form', 'allergy_form_facilities', 'allergy_form_log', 'allergy_form_options', 'allergy_formulation', 'allergy_formulation_maint_logs', 'allergy_general_setting ...
# 2025-04-10 18:07:30,395 - deIdentification.nd_logger - INFO - Added column: users_uname of type VARCHAR(60)
# 2025-04-10 18:07:30,395 - deIdentification.nd_logger - INFO - Added column: users_upwd of type VARCHAR(255)
# 2025-04-10 18:07:30,396 - deIdentification.nd_logger - INFO - Added column: users_umobileno of type VARCHAR(15)
# 2025-04-10 18:07:30,396 - deIdentification.nd_logger - INFO - Added column: users_upagerno of type VARCHAR(15)
# 2025-04-10 18:07:30,397 - deIdentification.nd_logger - INFO - Added column: users_ufname of type VARCHAR(60)
# 2025-04-10 18:07:30,397 - deIdentification.nd_logger - INFO - Added column: users_uminitial of type VARCHAR(60)
# 2025-04-10 18:07:30,397 - deIdentification.nd_logger - INFO - Added column: users_ulname of type VARCHAR(60)
# 2025-04-10 18:07:30,397 - deIdentification.nd_logger - INFO - Added column: users_uemail of type VARCHAR(255)
# 2025-04-10 18:07:30,398 - deIdentification.nd_logger - INFO - Added column: users_upaddress of type VARCHAR(60)
# 2025-04-10 18:07:30,398 - deIdentification.nd_logger - INFO - Added column: users_upcity of type VARCHAR(40)
# 2025-04-10 18:07:30,398 - deIdentification.nd_logger - INFO - Added column: users_upPhone of type VARCHAR(30)
# 2025-04-10 18:07:30,398 - deIdentification.nd_logger - INFO - Added column: users_UserType of type <class 'sqlalchemy.sql.sqltypes.Integer'>
# 2025-04-10 18:07:30,399 - deIdentification.nd_logger - INFO - Added column: users_dob of type VARCHAR(15)
# 2025-04-10 18:07:30,399 - deIdentification.nd_logger - INFO - Added column: users_ssn of type VARCHAR(30)
# 2025-04-10 18:07:30,399 - deIdentification.nd_logger - INFO - Added column: users_upaddress2 of type VARCHAR(50)
# 2025-04-10 18:07:30,399 - deIdentification.nd_logger - INFO - Added column: users_initials of type VARCHAR(10)
# 2025-04-10 18:07:30,400 - deIdentification.nd_logger - INFO - Added column: users_ptDob of type <class 'sqlalchemy.sql.sqltypes.Date'>
# 2025-04-10 18:07:30,400 - deIdentification.nd_logger - INFO - Added column: users_upreviousname of type VARCHAR(60)
# 2025-04-10 18:07:30,402 - deIdentification.nd_logger - INFO - Added column: patients_employername of type VARCHAR(100)
# 2025-04-10 18:07:30,402 - deIdentification.nd_logger - INFO - Added column: patients_employeraddress of type VARCHAR(55)
# 2025-04-10 18:07:30,402 - deIdentification.nd_logger - INFO - Added column: patients_employeraddress2 of type VARCHAR(55)
# 2025-04-10 18:07:30,402 - deIdentification.nd_logger - INFO - Added column: patients_employercity of type VARCHAR(40)
# 2025-04-10 18:07:30,403 - deIdentification.nd_logger - INFO - Added column: patients_employerPhone of type VARCHAR(25)
# 2025-04-10 18:07:30,403 - deIdentification.nd_logger - INFO - Added column: patients_insname of type VARCHAR(20)
# 2025-04-10 18:07:30,403 - deIdentification.nd_logger - INFO - Added column: patients_insgroupno of type VARCHAR(15)
# 2025-04-10 18:07:30,404 - deIdentification.nd_logger - INFO - Added column: patients_inssubscriberno of type VARCHAR(15)
# 2025-04-10 18:07:30,404 - deIdentification.nd_logger - INFO - Added column: patients_inscopay of type VARCHAR(15)
# 2025-04-10 18:07:30,404 - deIdentification.nd_logger - INFO - Added column: patients_insname2 of type VARCHAR(25)
# 2025-04-10 18:07:30,404 - deIdentification.nd_logger - INFO - Added column: patients_insgroupno2 of type VARCHAR(25)
# 2025-04-10 18:07:30,405 - deIdentification.nd_logger - INFO - Added column: patients_inssubscriberno2 of type VARCHAR(25)
# 2025-04-10 18:07:30,405 - deIdentification.nd_logger - INFO - Added column: patients_inscopay2 of type VARCHAR(15)
# 2025-04-10 18:07:30,405 - deIdentification.nd_logger - INFO - Added column: patients_straddress of type VARCHAR(60)
# 2025-04-10 18:07:30,405 - deIdentification.nd_logger - INFO - Added column: patients_city of type VARCHAR(40)
# 2025-04-10 18:07:30,406 - deIdentification.nd_logger - INFO - Added column: patients_insId of type <class 'sqlalchemy.sql.sqltypes.Integer'>
# 2025-04-10 18:07:30,406 - deIdentification.nd_logger - INFO - Added column: patients_insId2 of type <class 'sqlalchemy.sql.sqltypes.Integer'>
# 2025-04-10 18:07:30,406 - deIdentification.nd_logger - INFO - Added column: patients_strAddress2 of type VARCHAR(60)
# 2025-04-10 18:07:30,406 - deIdentification.nd_logger - INFO - Added column: patients_GrId of type <class 'sqlalchemy.sql.sqltypes.Integer'>
# 2025-04-10 18:07:30,407 - deIdentification.nd_logger - INFO - Added column: patients_preferred_name of type VARCHAR(255)
# 2025-04-10 18:07:30,420 - deIdentification.nd_logger - INFO - Table pii_data_table created successfully in the destination database!
# 2025-04-10 18:07:34,843 - deIdentification.nd_logger - INFO - Inserted batch 1 of 27 for pii_data_table.
# 2025-04-10 18:07:36,148 - deIdentification.nd_logger - INFO - Inserted batch 2 of 27 for pii_data_table.
# 2025-04-10 18:07:37,439 - deIdentification.nd_logger - INFO - Inserted batch 3 of 27 for pii_data_table.
# 2025-04-10 18:07:38,781 - deIdentification.nd_logger - INFO - Inserted batch 4 of 27 for pii_data_table.
# 2025-04-10 18:07:40,097 - deIdentification.nd_logger - INFO - Inserted batch 5 of 27 for pii_data_table.
# 2025-04-10 18:07:41,398 - deIdentification.nd_logger - INFO - Inserted batch 6 of 27 for pii_data_table.
# 2025-04-10 18:07:42,628 - deIdentification.nd_logger - INFO - Inserted batch 7 of 27 for pii_data_table.
# 2025-04-10 18:07:43,948 - deIdentification.nd_logger - INFO - Inserted batch 8 of 27 for pii_data_table.
# 2025-04-10 18:07:45,321 - deIdentification.nd_logger - INFO - Inserted batch 9 of 27 for pii_data_table.
# 2025-04-10 18:07:46,551 - deIdentification.nd_logger - INFO - Inserted batch 10 of 27 for pii_data_table.
# 2025-04-10 18:07:47,927 - deIdentification.nd_logger - INFO - Inserted batch 11 of 27 for pii_data_table.
# 2025-04-10 18:07:49,294 - deIdentification.nd_logger - INFO - Inserted batch 12 of 27 for pii_data_table.
# 2025-04-10 18:07:50,542 - deIdentification.nd_logger - INFO - Inserted batch 13 of 27 for pii_data_table.
# 2025-04-10 18:07:51,894 - deIdentification.nd_logger - INFO - Inserted batch 14 of 27 for pii_data_table.
# 2025-04-10 18:07:53,195 - deIdentification.nd_logger - INFO - Inserted batch 15 of 27 for pii_data_table.
# 2025-04-10 18:07:54,479 - deIdentification.nd_logger - INFO - Inserted batch 16 of 27 for pii_data_table.
# 2025-04-10 18:07:55,853 - deIdentification.nd_logger - INFO - Inserted batch 17 of 27 for pii_data_table.
# 2025-04-10 18:07:57,198 - deIdentification.nd_logger - INFO - Inserted batch 18 of 27 for pii_data_table.
# 2025-04-10 18:07:58,526 - deIdentification.nd_logger - INFO - Inserted batch 19 of 27 for pii_data_table.
# 2025-04-10 18:07:59,786 - deIdentification.nd_logger - INFO - Inserted batch 20 of 27 for pii_data_table.
# 2025-04-10 18:08:01,128 - deIdentification.nd_logger - INFO - Inserted batch 21 of 27 for pii_data_table.
# 2025-04-10 18:08:02,436 - deIdentification.nd_logger - INFO - Inserted batch 22 of 27 for pii_data_table.
# 2025-04-10 18:08:03,740 - deIdentification.nd_logger - INFO - Inserted batch 23 of 27 for pii_data_table.
# 2025-04-10 18:08:05,065 - deIdentification.nd_logger - INFO - Inserted batch 24 of 27 for pii_data_table.
# 2025-04-10 18:08:06,375 - deIdentification.nd_logger - INFO - Inserted batch 25 of 27 for pii_data_table.
# 2025-04-10 18:08:07,686 - deIdentification.nd_logger - INFO - Inserted batch 26 of 27 for pii_data_table.
# 2025-04-10 18:08:08,479 - deIdentification.nd_logger - INFO - Inserted batch 27 of 27 for pii_data_table.
# 2025-04-10 18:08:08,481 - deIdentification.nd_logger - INFO - Data from table pii_data_table successfully inserted/updated.
# 2025-04-10 18:08:13,014 - deIdentification.nd_logger - INFO - Inserted batch 1 of 26 for pii_data_table.
# 2025-04-10 18:08:14,565 - deIdentification.nd_logger - INFO - Inserted batch 2 of 26 for pii_data_table.
# 2025-04-10 18:08:16,114 - deIdentification.nd_logger - INFO - Inserted batch 3 of 26 for pii_data_table.
# 2025-04-10 18:08:17,717 - deIdentification.nd_logger - INFO - Inserted batch 4 of 26 for pii_data_table.
# 2025-04-10 18:08:19,318 - deIdentification.nd_logger - INFO - Inserted batch 5 of 26 for pii_data_table.
# 2025-04-10 18:08:20,880 - deIdentification.nd_logger - INFO - Inserted batch 6 of 26 for pii_data_table.
# 2025-04-10 18:08:22,425 - deIdentification.nd_logger - INFO - Inserted batch 7 of 26 for pii_data_table.
# 2025-04-10 18:08:24,054 - deIdentification.nd_logger - INFO - Inserted batch 8 of 26 for pii_data_table.
# 2025-04-10 18:08:25,644 - deIdentification.nd_logger - INFO - Inserted batch 9 of 26 for pii_data_table.
# 2025-04-10 18:08:27,139 - deIdentification.nd_logger - INFO - Inserted batch 10 of 26 for pii_data_table.
# 2025-04-10 18:08:28,739 - deIdentification.nd_logger - INFO - Inserted batch 11 of 26 for pii_data_table.
# 2025-04-10 18:08:30,343 - deIdentification.nd_logger - INFO - Inserted batch 12 of 26 for pii_data_table.
# 2025-04-10 18:08:32,028 - deIdentification.nd_logger - INFO - Inserted batch 13 of 26 for pii_data_table.
# 2025-04-10 18:08:33,612 - deIdentification.nd_logger - INFO - Inserted batch 14 of 26 for pii_data_table.
# 2025-04-10 18:08:35,111 - deIdentification.nd_logger - INFO - Inserted batch 15 of 26 for pii_data_table.
# 2025-04-10 18:08:36,709 - deIdentification.nd_logger - INFO - Inserted batch 16 of 26 for pii_data_table.
# 2025-04-10 18:08:38,434 - deIdentification.nd_logger - INFO - Inserted batch 17 of 26 for pii_data_table.
# 2025-04-10 18:08:39,953 - deIdentification.nd_logger - INFO - Inserted batch 18 of 26 for pii_data_table.
# 2025-04-10 18:08:41,566 - deIdentification.nd_logger - INFO - Inserted batch 19 of 26 for pii_data_table.
# 2025-04-10 18:08:43,260 - deIdentification.nd_logger - INFO - Inserted batch 20 of 26 for pii_data_table.
# 2025-04-10 18:08:44,776 - deIdentification.nd_logger - INFO - Inserted batch 21 of 26 for pii_data_table.
# 2025-04-10 18:08:46,416 - deIdentification.nd_logger - INFO - Inserted batch 22 of 26 for pii_data_table.
# 2025-04-10 18:08:48,165 - deIdentification.nd_logger - INFO - Inserted batch 23 of 26 for pii_data_table.
# 2025-04-10 18:08:49,682 - deIdentification.nd_logger - INFO - Inserted batch 24 of 26 for pii_data_table.
# 2025-04-10 18:08:51,284 - deIdentification.nd_logger - INFO - Inserted batch 25 of 26 for pii_data_table.
# 2025-04-10 18:08:52,275 - deIdentification.nd_logger - INFO - Inserted batch 26 of 26 for pii_data_table.
# 2025-04-10 18:08:52,278 - deIdentification.nd_logger - INFO - Data from table pii_data_table successfully inserted/updated.

# %%
import os
import django
import sys

# Set up Django environment
sys.path.append(
    "/nd_deployment/deIdentification/"
)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "deIdentification.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

from core.dbPkg.phi_table.create_table import PIITable

insurance_table_config = {
    "insurance_details": {
        "primary_column_name": None,
        "upsert_instead_of_append": True,
        "tables": {
            "hcfa": {
                "primary_col": None,
                "other_required_columns": [
                    "PName",
                    "InsuredName",
                    "InsuredId",
                    "PAddressStreet",
                    "PAddressCity",
                    "InsuredAddStreet",
                    "InsuredAddCity",
                    "NameRef",
                    "SSN",
                    "EmpOrSchoolName",
                    "InsurancePlan",
                    "OtherInsuredName",
                    "OtherEmpName",
                    "OtherInsuranceName",
                    "PayorName1",
                    "PayorName2",
                    "PayorName3",
                    "PayorAddress11",
                    "PayorAddress12",
                    "PayorAddress13",
                    "PayorAddress21",
                    "PayorAddress22",
                    "PayorAddress23",
                    "PayorCity1",
                    "PayorZip1",
                    "PayorCity2",
                    "PayorZip2",
                    "PayorCity3",
                    "PayorZip3"
                ],
            }
        },
    }
}



import urllib.parse

encoded_password = urllib.parse.quote_plus("ndADMIN@2025")
# Connection String with Encoded Password
#src_db_url = "mssql+pyodbc://sa:ndADMIN2025@host.docker.internal:1433/mobiledoc?driver=ODBC+Driver+17+for+SQL+Server"
src_db_url = 'mysql+pymysql://ndadmin:ndADMIN%402025@host.docker.internal:3306/mobiledoc'


dest_db_url = f"mysql+pymysql://ndadmin:{encoded_password}@host.docker.internal:3306/master"
dest_db_url = 'mysql+pymysql://ndadmin:ndADMIN%402025@host.docker.internal:3306/master'


# src_db_url = "mysql+pymysql://root:Texas%402025@localhost/mobiledoc"
# dest_db_url = "mysql+pymysql://root:Texas%402025@localhost/master"
pii = PIITable(src_db_url, dest_db_url, pii_table_config)
pii.generate_pii_tables()
